# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dataset_5secondWindow.csv', index_col=0)
df1 = df.copy()
df1
# Out:
#          id   time  activityrecognition#0  activityrecognition#1  \
# 0     16170   78.0                    NaN                  100.0
# 1     15871  145.0                    NaN                  100.0
# 2     16811  150.0                    NaN                  100.0
# 3     15831  105.0                    NaN                   77.0
# 4       876   77.0                    NaN                  100.0
# ...     ...    ...                    ...                    ...
# 5888  14125    4.0                    NaN                  100.0
# 5889  19582   32.0                    NaN                   10.0
# 5890  16178   86.0                    NaN                  100.0
# 5891  10973  199.0                    NaN                  100.0
# 5892   8278   55.0                    NaN                  100.0
#
#       android.sensor.accelerometer#mean  android.sensor.accelerometer#min  \
# 0                              9.811476                          9.758895
# 1                              9.939207                          7.707437
# 2                              9.827178                          9.804817
# 3                              9.673039                          7.659674
# 4                              9.993466                          8.965621
# ...                                 ...                               ...
# 5888                          10.066610                          4.564648
# 5889                           9.964271                          8.768007
# 5890                           9.812893                          9.772881
# 5891                           9.831144                          9.807347
# 5892                          11.051009                          5.203285
#
#       android.sensor.accelerometer#max  android.sensor.accelerometer#std  \
# 0                             9.849411                          0.014626
# 1                            17.146631                          1.775944
# 2                             9.849262                          0.011199
# 3                            12.304298                          0.862553
# 4                            10.891645                          0.504117
# ...                                ...                               ...
# 5888                         13.414389                          3.373972
# 5889                         11.454213                          0.665529
# 5890                          9.862587                          0.017633
# 5891                          9.874450                          0.013485
# 5892                         19.921068                          4.745098
#
#       android.sensor.game_rotation_vector#mean  \
# 0                                     0.029340
# 1                                     0.999925
# 2                                     0.665215
# 3                                     0.996221
# 4                                     0.563792
# ...                                        ...
# 5888                                  0.986319
# 5889                                  0.648602
# 5890                                  0.024392
# 5891                                  0.481212
# 5892                                  0.919815
#
#       android.sensor.game_rotation_vector#min  ...  sound#mean  sound#min  \
# 0                                    0.029014  ...         NaN        NaN
# 1                                    0.999903  ...   89.200210  89.065143
# 2                                    0.665213  ...         NaN        NaN
# 3                                    0.993781  ...   87.470377  87.470377
# 4                                    0.521799  ...   89.770732  89.770732
# ...                                       ...  ...         ...        ...
# 5888                                 0.974523  ...         NaN        NaN
# 5889                                 0.648343  ...         NaN        NaN
# 5890                                 0.024081  ...         NaN        NaN
# 5891                                 0.481209  ...         NaN        NaN
# 5892                                 0.892571  ...   89.712441  89.712441
#
#       sound#max  sound#std  speed#mean  speed#min  speed#max  speed#std  \
# 0           NaN        NaN    0.000000   0.000000   0.000000   0.000000
# 1     89.335277   0.191013   16.539349  16.539349  16.539349   0.628595
# 2           NaN        NaN    0.000000   0.000000   0.000000   0.000000
# 3     87.470377   2.284186   17.739895  17.739895  17.739895   0.628595
# 4     89.770732   0.006389    9.000000   9.000000   9.000000        NaN
# ...         ...        ...         ...        ...        ...        ...
# 5888        NaN        NaN         NaN        NaN        NaN        NaN
# 5889        NaN        NaN   31.960054  31.960054  31.960054        NaN
# 5890        NaN        NaN    0.000000   0.000000   0.000000   0.000000
# 5891        NaN        NaN    1.090415   1.090415   1.090415        NaN
# 5892  89.712441   0.006400    0.750000   0.750000   0.750000        NaN
#
#        target  user
# 0       Still   U12
# 1         Car   U12
# 2       Still   U12
# 3         Car   U12
# 4         Car    U1
# ...       ...   ...
# 5888  Walking    U2
# 5889    Train    U3
# 5890    Still   U12
# 5891    Still   U10
# 5892  Walking    U1
#
# [5893 rows x 70 columns]

# %%
df1.columns
# Out:
# Index(['id', 'time', 'activityrecognition#0', 'activityrecognition#1',
#        'android.sensor.accelerometer#mean', 'android.sensor.accelerometer#min',
#        'android.sensor.accelerometer#max', 'android.sensor.accelerometer#std',
#        'android.sensor.game_rotation_vector#mean',
#        'android.sensor.game_rotation_vector#min',
#        'android.sensor.game_rotation_vector#max',
#        'android.sensor.game_rotation_vector#std',
#        'android.sensor.gravity#mean', 'android.sensor.gravity#min',
#        'android.sensor.gravity#max', 'android.sensor.gravity#std',
#        'android.sensor.gyroscope#mean', 'android.sensor.gyroscope#min',
#        'android.sensor.gyroscope#max', 'android.sensor.gyroscope#std',
#        'android.sensor.gyroscope_uncalibrated#mean',
#        'android.sensor.gyroscope_uncalibrated#min',
#        'android.sensor.gyroscope_uncalibrated#max',
#        'android.sensor.gyroscope_uncalibrated#std',
#        'android.sensor.light#mean', 'android.sensor.light#min',
#        'android.sensor.light#max', 'android.sensor.light#std',
#        'android.sensor.linear_acceleration#mean',
#        'android.sensor.linear_acceleration#min',
#        'android.sensor.linear_acceleration#max',
#        'android.sensor.linear_acceleration#std',
#        'android.sensor.magnetic_field#mean',
#        'android.sensor.magnetic_field#min',
#        'android.sensor.magnetic_field#max',
#        'android.sensor.magnetic_field#std',
#        'android.sensor.magnetic_field_uncalibrated#mean',
#        'android.sensor.magnetic_field_uncalibrated#min',
#        'android.sensor.magnetic_field_uncalibrated#max',
#        'android.sensor.magnetic_field_uncalibrated#std',
#        'android.sensor.orientation#mean', 'android.sensor.orientation#min',
#        'android.sensor.orientation#max', 'android.sensor.orientation#std',
#        'android.sensor.pressure#mean', 'android.sensor.pressure#min',
#        'android.sensor.pressure#max', 'android.sensor.pressure#std',
#        'android.sensor.proximity#mean', 'android.sensor.proximity#min',
#        'android.sensor.proximity#max', 'android.sensor.proximity#std',
#        'android.sensor.rotation_vector#mean',
#        'android.sensor.rotation_vector#min',
#        'android.sensor.rotation_vector#max',
#        'android.sensor.rotation_vector#std',
#        'android.sensor.step_counter#mean', 'android.sensor.step_counter#min',
#        'android.sensor.step_counter#max', 'android.sensor.step_counter#std',
#        'sound#mean', 'sound#min', 'sound#max', 'sound#std', 'speed#mean',
#        'speed#min', 'speed#max', 'speed#std', 'target', 'user'],
#       dtype='object')

# %%
sorted(df1['user'].unique())
a
# Out:
# ['U1',
#  'U10',
#  'U11',
#  'U12',
#  'U13',
#  'U2',
#  'U3',
#  'U4',
#  'U5',
#  'U6',
#  'U7',
#  'U8',
#  'U9']

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5893 entries, 0 to 5892
# Data columns (total 70 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   id                                               5893 non-null   int64
#  1   time                                             5893 non-null   float64
#  2   activityrecognition#0                            0 non-null      float64
#  3   activityrecognition#1                            5893 non-null   float64
#  4   android.sensor.accelerometer#mean                5893 non-null   float64
#  5   android.sensor.accelerometer#min                 5893 non-null   float64
#  6   android.sensor.accelerometer#max                 5893 non-null   float64
#  7   android.sensor.accelerometer#std                 5893 non-null   float64
#  8   android.sensor.game_rotation_vector#mean         5094 non-null   float64
#  9   android.sensor.game_rotation_vector#min          5094 non-null   float64
#  10  android.sensor.game_rotation_vector#max          5094 non-null   float64
#  11  android.sensor.game_rotation_vector#std          5093 non-null   float64
#  12  android.sensor.gravity#mean                      5396 non-null   float64
#  13  android.sensor.gravity#min                       5396 non-null   float64
#  14  android.sensor.gravity#max                       5396 non-null   float64
#  15  android.sensor.gravity#std                       5356 non-null   float64
#  16  android.sensor.gyroscope#mean                    5173 non-null   float64
#  17  android.sensor.gyroscope#min                     5173 non-null   float64
#  18  android.sensor.gyroscope#max                     5173 non-null   float64
#  19  android.sensor.gyroscope#std                     5172 non-null   float64
#  20  android.sensor.gyroscope_uncalibrated#mean       5094 non-null   float64
#  21  android.sensor.gyroscope_uncalibrated#min        5094 non-null   float64
#  22  android.sensor.gyroscope_uncalibrated#max        5094 non-null   float64
#  23  android.sensor.gyroscope_uncalibrated#std        5094 non-null   float64
#  24  android.sensor.light#mean                        4381 non-null   float64
#  25  android.sensor.light#min                         4381 non-null   float64
#  26  android.sensor.light#max                         4381 non-null   float64
#  27  android.sensor.light#std                         2124 non-null   float64
#  28  android.sensor.linear_acceleration#mean          5399 non-null   float64
#  29  android.sensor.linear_acceleration#min           5399 non-null   float64
#  30  android.sensor.linear_acceleration#max           5399 non-null   float64
#  31  android.sensor.linear_acceleration#std           5370 non-null   float64
#  32  android.sensor.magnetic_field#mean               5400 non-null   float64
#  33  android.sensor.magnetic_field#min                5400 non-null   float64
#  34  android.sensor.magnetic_field#max                5400 non-null   float64
#  35  android.sensor.magnetic_field#std                5383 non-null   float64
#  36  android.sensor.magnetic_field_uncalibrated#mean  5094 non-null   float64
#  37  android.sensor.magnetic_field_uncalibrated#min   5094 non-null   float64
#  38  android.sensor.magnetic_field_uncalibrated#max   5094 non-null   float64
#  39  android.sensor.magnetic_field_uncalibrated#std   5087 non-null   float64
#  40  android.sensor.orientation#mean                  5396 non-null   float64
#  41  android.sensor.orientation#min                   5396 non-null   float64
#  42  android.sensor.orientation#max                   5396 non-null   float64
#  43  android.sensor.orientation#std                   5373 non-null   float64
#  44  android.sensor.pressure#mean                     1918 non-null   float64
#  45  android.sensor.pressure#min                      1918 non-null   float64
#  46  android.sensor.pressure#max                      1918 non-null   float64
#  47  android.sensor.pressure#std                      1128 non-null   float64
#  48  android.sensor.proximity#mean                    1119 non-null   float64
#  49  android.sensor.proximity#min                     1119 non-null   float64
#  50  android.sensor.proximity#max                     1119 non-null   float64
#  51  android.sensor.proximity#std                     283 non-null    float64
#  52  android.sensor.rotation_vector#mean              5172 non-null   float64
#  53  android.sensor.rotation_vector#min               5172 non-null   float64
#  54  android.sensor.rotation_vector#max               5172 non-null   float64
#  55  android.sensor.rotation_vector#std               5163 non-null   float64
#  56  android.sensor.step_counter#mean                 1487 non-null   float64
#  57  android.sensor.step_counter#min                  1487 non-null   float64
#  58  android.sensor.step_counter#max                  1487 non-null   float64
#  59  android.sensor.step_counter#std                  232 non-null    float64
#  60  sound#mean                                       4899 non-null   float64
#  61  sound#min                                        4899 non-null   float64
#  62  sound#max                                        4899 non-null   float64
#  63  sound#std                                        4062 non-null   float64
#  64  speed#mean                                       3520 non-null   float64
#  65  speed#min                                        3520 non-null   float64
#  66  speed#max                                        3520 non-null   float64
#  67  speed#std                                        1318 non-null   float64
#  68  target                                           5893 non-null   object
#  69  user                                             5893 non-null   object
# dtypes: float64(67), int64(1), object(2)
# memory usage: 3.2+ MB

# %%
df1.columns
# Out:
# Index(['id', 'time', 'activityrecognition#0', 'activityrecognition#1',
#        'android.sensor.accelerometer#mean', 'android.sensor.accelerometer#min',
#        'android.sensor.accelerometer#max', 'android.sensor.accelerometer#std',
#        'android.sensor.game_rotation_vector#mean',
#        'android.sensor.game_rotation_vector#min',
#        'android.sensor.game_rotation_vector#max',
#        'android.sensor.game_rotation_vector#std',
#        'android.sensor.gravity#mean', 'android.sensor.gravity#min',
#        'android.sensor.gravity#max', 'android.sensor.gravity#std',
#        'android.sensor.gyroscope#mean', 'android.sensor.gyroscope#min',
#        'android.sensor.gyroscope#max', 'android.sensor.gyroscope#std',
#        'android.sensor.gyroscope_uncalibrated#mean',
#        'android.sensor.gyroscope_uncalibrated#min',
#        'android.sensor.gyroscope_uncalibrated#max',
#        'android.sensor.gyroscope_uncalibrated#std',
#        'android.sensor.light#mean', 'android.sensor.light#min',
#        'android.sensor.light#max', 'android.sensor.light#std',
#        'android.sensor.linear_acceleration#mean',
#        'android.sensor.linear_acceleration#min',
#        'android.sensor.linear_acceleration#max',
#        'android.sensor.linear_acceleration#std',
#        'android.sensor.magnetic_field#mean',
#        'android.sensor.magnetic_field#min',
#        'android.sensor.magnetic_field#max',
#        'android.sensor.magnetic_field#std',
#        'android.sensor.magnetic_field_uncalibrated#mean',
#        'android.sensor.magnetic_field_uncalibrated#min',
#        'android.sensor.magnetic_field_uncalibrated#max',
#        'android.sensor.magnetic_field_uncalibrated#std',
#        'android.sensor.orientation#mean', 'android.sensor.orientation#min',
#        'android.sensor.orientation#max', 'android.sensor.orientation#std',
#        'android.sensor.pressure#mean', 'android.sensor.pressure#min',
#        'android.sensor.pressure#max', 'android.sensor.pressure#std',
#        'android.sensor.proximity#mean', 'android.sensor.proximity#min',
#        'android.sensor.proximity#max', 'android.sensor.proximity#std',
#        'android.sensor.rotation_vector#mean',
#        'android.sensor.rotation_vector#min',
#        'android.sensor.rotation_vector#max',
#        'android.sensor.rotation_vector#std',
#        'android.sensor.step_counter#mean', 'android.sensor.step_counter#min',
#        'android.sensor.step_counter#max', 'android.sensor.step_counter#std',
#        'sound#mean', 'sound#min', 'sound#max', 'sound#std', 'speed#mean',
#        'speed#min', 'speed#max', 'speed#std', 'target', 'user'],
#       dtype='object')

# %%
from sklearn.preprocessing import OrdinalEncoder

enc = OrdinalEncoder()
cat_data = ['user','target']

# %%
import seaborn as sns

# %%
fig, ax = plt.subplots(figsize=(20,20))
ax = sns.heatmap((df1.drop(['target', 'user', 'id', 'activityrecognition#0'], axis=1)).corr(), annot=True)

# %%
a = df1.columns.to_list()
# Out:
# ['id',
#  'time',
#  'activityrecognition#0',
#  'activityrecognition#1',
#  'android.sensor.accelerometer#mean',
#  'android.sensor.accelerometer#min',
#  'android.sensor.accelerometer#max',
#  'android.sensor.accelerometer#std',
#  'android.sensor.game_rotation_vector#mean',
#  'android.sensor.game_rotation_vector#min',
#  'android.sensor.game_rotation_vector#max',
#  'android.sensor.game_rotation_vector#std',
#  'android.sensor.gravity#mean',
#  'android.sensor.gravity#min',
#  'android.sensor.gravity#max',
#  'android.sensor.gravity#std',
#  'android.sensor.gyroscope#mean',
#  'android.sensor.gyroscope#min',
#  'android.sensor.gyroscope#max',
#  'android.sensor.gyroscope#std',
#  'android.sensor.gyroscope_uncalibrated#mean',
#  'android.sensor.gyroscope_uncalibrated#min',
#  'android.sensor.gyroscope_uncalibrated#max',
#  'android.sensor.gyroscope_uncalibrated#std',
#  'android.sensor.light#mean',
#  'android.sensor.light#min',
#  'android.sensor.light#max',
#  'android.sensor.light#std',
#  'android.sensor.linear_acceleration#mean',
#  'android.sensor.linear_acceleration#min',
#  'android.sensor.linear_acceleration#max',
#  'android.sensor.linear_acceleration#std',
#  'android.sensor.magnetic_field#mean',
#  'android.sensor.magnetic_field#min',
#  'android.sensor.magnetic_field#max',
#  'android.sensor.magnetic_field#std',
#  'android.sensor.magnetic_field_uncalibrated#mean',
#  'android.sensor.magnetic_field_uncalibrated#min',
#  'android.sensor.magnetic_field_uncalibrated#max',
#  'android.sensor.magnetic_field_uncalibrated#std',
#  'android.sensor.orientation#mean',
#  'android.sensor.orientation#min',
#  'android.sensor.orientation#max',
#  'android.sensor.orientation#std',
#  'android.sensor.pressure#mean',
#  'android.sensor.pressure#min',
#  'android.sensor.pressure#max',
#  'android.sensor.pressure#std',
#  'android.sensor.proximity#mean',
#  'android.sensor.proximity#min',
#  'android.sensor.proximity#max',
#  'android.sensor.proximity#std',
#  'android.sensor.rotation_vector#mean',
#  'android.sensor.rotation_vector#min',
#  'android.sensor.rotation_vector#max',
#  'android.sensor.rotation_vector#std',
#  'android.sensor.step_counter#mean',
#  'android.sensor.step_counter#min',
#  'android.sensor.step_counter#max',
#  'android.sensor.step_counter#std',
#  'sound#mean',
#  'sound#min',
#  'sound#max',
#  'sound#std',
#  'speed#mean',
#  'speed#min',
#  'speed#max',
#  'speed#std',
#  'target',
#  'user']

# %%
df1_drop_by_corr = df1.drop(['android.sensor.accelerometer#min','android.sensor.accelerometer#max',
'android.sensor.game_rotation_vector#min',
'android.sensor.game_rotation_vector#max', 'android.sensor.gravity#min',
 'android.sensor.gravity#max',  'android.sensor.gyroscope#min',
 'android.sensor.gyroscope#max', 'android.sensor.gyroscope_uncalibrated#min',
 'android.sensor.gyroscope_uncalibrated#max', 'speed#min',
 'speed#max', 'android.sensor.light#min',
 'android.sensor.light#max', 'android.sensor.linear_acceleration#min',
 'android.sensor.linear_acceleration#max','android.sensor.magnetic_field#min',
 'android.sensor.magnetic_field#max', 'android.sensor.magnetic_field_uncalibrated#min',
 'android.sensor.magnetic_field_uncalibrated#max', 'android.sensor.orientation#min',
 'android.sensor.orientation#max', 'android.sensor.pressure#min',
 'android.sensor.pressure#max', 'android.sensor.proximity#min',
 'android.sensor.proximity#max', 'android.sensor.rotation_vector#min',
 'android.sensor.rotation_vector#max','android.sensor.step_counter#min',
 'android.sensor.step_counter#max', 'sound#min',
 'sound#max','id', 'activityrecognition#0'], axis=1)

# %%
a = df1_drop_by_corr.columns.to_list()
a
# Out:
# ['time',
#  'activityrecognition#1',
#  'android.sensor.accelerometer#mean',
#  'android.sensor.accelerometer#std',
#  'android.sensor.game_rotation_vector#mean',
#  'android.sensor.game_rotation_vector#std',
#  'android.sensor.gravity#mean',
#  'android.sensor.gravity#std',
#  'android.sensor.gyroscope#mean',
#  'android.sensor.gyroscope#std',
#  'android.sensor.gyroscope_uncalibrated#mean',
#  'android.sensor.gyroscope_uncalibrated#std',
#  'android.sensor.light#mean',
#  'android.sensor.light#std',
#  'android.sensor.linear_acceleration#mean',
#  'android.sensor.linear_acceleration#std',
#  'android.sensor.magnetic_field#mean',
#  'android.sensor.magnetic_field#std',
#  'android.sensor.magnetic_field_uncalibrated#mean',
#  'android.sensor.magnetic_field_uncalibrated#std',
#  'android.sensor.orientation#mean',
#  'android.sensor.orientation#std',
#  'android.sensor.pressure#mean',
#  'android.sensor.pressure#std',
#  'android.sensor.proximity#mean',
#  'android.sensor.proximity#std',
#  'android.sensor.rotation_vector#mean',
#  'android.sensor.rotation_vector#std',
#  'android.sensor.step_counter#mean',
#  'android.sensor.step_counter#std',
#  'sound#mean',
#  'sound#std',
#  'speed#mean',
#  'speed#std',
#  'target',
#  'user']

# %%
df1_drop_by_corr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5893 entries, 0 to 5892
# Data columns (total 36 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   time                                             5893 non-null   float64
#  1   activityrecognition#1                            5893 non-null   float64
#  2   android.sensor.accelerometer#mean                5893 non-null   float64
#  3   android.sensor.accelerometer#std                 5893 non-null   float64
#  4   android.sensor.game_rotation_vector#mean         5094 non-null   float64
#  5   android.sensor.game_rotation_vector#std          5093 non-null   float64
#  6   android.sensor.gravity#mean                      5396 non-null   float64
#  7   android.sensor.gravity#std                       5356 non-null   float64
#  8   android.sensor.gyroscope#mean                    5173 non-null   float64
#  9   android.sensor.gyroscope#std                     5172 non-null   float64
#  10  android.sensor.gyroscope_uncalibrated#mean       5094 non-null   float64
#  11  android.sensor.gyroscope_uncalibrated#std        5094 non-null   float64
#  12  android.sensor.light#mean                        4381 non-null   float64
#  13  android.sensor.light#std                         2124 non-null   float64
#  14  android.sensor.linear_acceleration#mean          5399 non-null   float64
#  15  android.sensor.linear_acceleration#std           5370 non-null   float64
#  16  android.sensor.magnetic_field#mean               5400 non-null   float64
#  17  android.sensor.magnetic_field#std                5383 non-null   float64
#  18  android.sensor.magnetic_field_uncalibrated#mean  5094 non-null   float64
#  19  android.sensor.magnetic_field_uncalibrated#std   5087 non-null   float64
#  20  android.sensor.orientation#mean                  5396 non-null   float64
#  21  android.sensor.orientation#std                   5373 non-null   float64
#  22  android.sensor.pressure#mean                     1918 non-null   float64
#  23  android.sensor.pressure#std                      1128 non-null   float64
#  24  android.sensor.proximity#mean                    1119 non-null   float64
#  25  android.sensor.proximity#std                     283 non-null    float64
#  26  android.sensor.rotation_vector#mean              5172 non-null   float64
#  27  android.sensor.rotation_vector#std               5163 non-null   float64
#  28  android.sensor.step_counter#mean                 1487 non-null   float64
#  29  android.sensor.step_counter#std                  232 non-null    float64
#  30  sound#mean                                       4899 non-null   float64
#  31  sound#std                                        4062 non-null   float64
#  32  speed#mean                                       3520 non-null   float64
#  33  speed#std                                        1318 non-null   float64
#  34  target                                           5893 non-null   object
#  35  user                                             5893 non-null   object
# dtypes: float64(34), object(2)
# memory usage: 1.8+ MB

# %%
fig, ax = plt.subplots(figsize=(20,20))
ax = sns.heatmap(df1_drop_by_corr.corr(), annot=True)

# %%
#dropping the highly (more than 0.7) correlated features

df1_drop_by_corr1 = df1_drop_by_corr.drop(['android.sensor.accelerometer#mean','android.sensor.linear_acceleration#mean',
'android.sensor.gyroscope#mean', 
'android.sensor.pressure#mean','android.sensor.gyroscope_uncalibrated#mean',
'android.sensor.accelerometer#std','android.sensor.linear_acceleration#std',
'android.sensor.gyroscope_uncalibrated#std','android.sensor.gyroscope#std','android.sensor.light#mean','accelerometer#std_tion#std',
'gyrscope_uncalibrated#std', 'android.sensor.light#std', 'android.sensor.pressure#std',
'android.sensor.proximity#mean','android.sensor.proximity#std', 'android.sensor.step_counter#mean', 'speed#mean','sound#std',
'android.sensor.game_rotation_vector#mean', 'android.sensor.gravity#mean', 'android.sensor.step_counter#std' ,'speed#std'

], axis=1)

# %%
df1_drop_by_corr2 = df1_drop_by_corr1.dropna()

# %%
df1_drop_by_corr2['game_rot_vec_std'] = df1_drop_by_corr2.apply(lambda a: 
(a['android.sensor.rotation_vector#std']+a['android.sensor.game_rotation_vector#std'])/2, axis=1)
# Out:
# <ipython-input-317-4d8d1f7eccd5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_drop_by_corr2['game_rot_vec_std'] = df1_drop_by_corr2.apply(lambda a:

# %%
df1_drop_by_corr2['mag_field_mean'] = df1_drop_by_corr2.apply(lambda b: 
(b['android.sensor.magnetic_field_uncalibrated#mean'] + b['android.sensor.magnetic_field#mean'])/2, axis=1)

# %%
df1_drop_by_corr2 = df1_drop_by_corr2.drop([
'android.sensor.magnetic_field_uncalibrated#mean','android.sensor.magnetic_field#mean', 
], axis=1)

# %%
df1_drop_by_corr2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4117 entries, 1 to 5892
# Data columns (total 14 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   time                                            4117 non-null   float64
#  1   activityrecognition#1                           4117 non-null   float64
#  2   android.sensor.gravity#std                      4117 non-null   float64
#  3   android.sensor.magnetic_field#std               4117 non-null   float64
#  4   android.sensor.magnetic_field_uncalibrated#std  4117 non-null   float64
#  5   android.sensor.orientation#mean                 4117 non-null   float64
#  6   android.sensor.orientation#std                  4117 non-null   float64
#  7   android.sensor.rotation_vector#mean             4117 non-null   float64
#  8   sound#mean                                      4117 non-null   float64
#  9   target                                          4117 non-null   object
#  10  user                                            4117 non-null   object
#  11  new4_std                                        4117 non-null   float64
#  12  game_rot_vec_std                                4117 non-null   float64
#  13  mag_field_mean                                  4117 non-null   float64
# dtypes: float64(12), object(2)
# memory usage: 482.5+ KB

# %%
fig, ax = plt.subplots(figsize=(20,20))
ax = sns.heatmap(df1_drop_by_corr2.corr(), vmax=1, vmin=-1, annot=True)

# %%
a = pd.pivot_table(df1_drop_by_corr1, index=['user', 'target'])
a
# Out:
#               activityrecognition#1  android.sensor.game_rotation_vector#std  \
# user target
# U1   Bus                  76.437803                                 0.010381
#      Car                  92.463007                                 0.009766
#      Still               100.000000                                 0.000333
#      Train                81.309295                                 0.000853
#      Walking              91.430131                                 0.026929
# U10  Car                  85.824742                                 0.025520
#      Still                95.168766                                 0.010997
#      Walking              77.945946                                 0.054894
# U11  Car                  90.011976                                 0.008609
# U12  Bus                  74.833333                                 0.008336
#      Car                  90.007752                                 0.014726
#      Still                99.915441                                 0.002382
#      Train                96.520548                                 0.003243
#      Walking              95.761905                                 0.074336
# U13  Car                  85.166667                                 0.010002
# U2   Car                 100.000000                                 0.020423
#      Still                71.733333                                 0.003460
#      Walking              93.546667                                 0.010451
# U3   Bus                  91.615854                                 0.008311
#      Train                74.545455                                 0.000508
#      Walking              55.406504                                 0.033249
# U4   Car                  96.000000                                      NaN
#      Still               100.000000                                      NaN
#      Walking              97.490798                                      NaN
# U5   Still                92.333333                                 0.018262
#      Walking             100.000000                                 0.031485
# U6   Bus                  48.000000                                      NaN
#      Car                  82.280702                                      NaN
#      Still               100.000000                                      NaN
#      Train               100.000000                                      NaN
#      Walking             100.000000                                      NaN
# U7   Bus                  87.575342                                 0.013216
#      Train                86.374502                                 0.011869
# U8   Car                  97.374332                                      NaN
#      Still               100.000000                                      NaN
# U9   Train                16.761905                                      NaN
#      Walking              94.864865                                      NaN
#
#               android.sensor.gravity#std  android.sensor.magnetic_field#mean  \
# user target
# U1   Bus                    3.838004e-07                           36.007278
#      Car                    2.983999e-07                           94.572711
#      Still                  2.804420e-07                           46.033092
#      Train                  3.670707e-07                           64.109232
#      Walking                4.066247e-07                           45.279105
# U10  Car                    2.646910e-05                           44.108281
#      Still                  2.320328e-05                           41.953635
#      Walking                6.328146e-04                           61.074605
# U11  Car                    2.254041e-06                           33.803947
# U12  Bus                    2.776811e-06                           36.465704
#      Car                    2.679594e-06                           41.315440
#      Still                  4.200528e-07                           48.589750
#      Train                  2.472311e-06                           63.107089
#      Walking                6.599242e-06                           44.175708
# U13  Car                    3.609433e-06                          147.159945
# U2   Car                    2.338681e-07                           17.609143
#      Still                  3.663143e-07                           43.506267
#      Walking                3.611000e-07                           45.528594
# U3   Bus                    7.828434e-07                           72.918715
#      Train                  3.857440e-07                           41.363753
#      Walking                5.639207e-07                           39.035221
# U4   Car                    1.347527e-03                           36.846666
#      Still                  5.309430e-04                           40.272175
#      Walking                3.684089e-03                           40.039570
# U5   Still                  6.873894e-06                          141.070761
#      Walking                5.310202e-06                           58.627794
# U6   Bus                             NaN                                 NaN
#      Car                             NaN                                 NaN
#      Still                           NaN                                 NaN
#      Train                           NaN                                 NaN
#      Walking                         NaN                                 NaN
# U7   Bus                    2.415092e-06                           45.830456
#      Train                  1.767826e-06                          113.922679
# U8   Car                             NaN                                 NaN
#      Still                           NaN                                 NaN
# U9   Train                  2.915487e-07                          151.509332
#      Walking                7.568910e-07                           42.646330
#
#               android.sensor.magnetic_field#std  \
# user target
# U1   Bus                               1.432987
#      Car                               1.735604
#      Still                             0.712234
#      Train                             3.335478
#      Walking                           1.875091
# U10  Car                               1.773030
#      Still                             1.138032
#      Walking                           2.183664
# U11  Car                               0.932135
# U12  Bus                               0.639775
#      Car                               0.888399
#      Still                             0.287715
#      Train                             3.634325
#      Walking                           2.193982
# U13  Car                               0.475858
# U2   Car                               1.197898
#      Still                             0.420527
#      Walking                           1.853034
# U3   Bus                               1.885256
#      Train                             2.609794
#      Walking                           4.127205
# U4   Car                               1.966957
#      Still                             0.594308
#      Walking                           1.805714
# U5   Still                             2.190061
#      Walking                           3.359038
# U6   Bus                                    NaN
#      Car                                    NaN
#      Still                                  NaN
#      Train                                  NaN
#      Walking                                NaN
# U7   Bus                               0.949615
#      Train                             2.548184
# U8   Car                                    NaN
#      Still                                  NaN
# U9   Train                             3.697087
#      Walking                           2.354397
#
#               android.sensor.magnetic_field_uncalibrated#mean  \
# user target
# U1   Bus                                           142.797890
#      Car                                           172.564530
#      Still                                         131.433428
#      Train                                         132.845062
#      Walking                                       134.023776
# U10  Car                                           290.473669
#      Still                                         259.594475
#      Walking                                       301.033317
# U11  Car                                            74.033880
# U12  Bus                                            52.967315
#      Car                                            76.780775
#      Still                                          41.947846
#      Train                                          87.607184
#      Walking                                        91.173829
# U13  Car                                           252.860885
# U2   Car                                           101.084722
#      Still                                          93.709366
#      Walking                                        82.503156
# U3   Bus                                            79.429583
#      Train                                          89.360799
#      Walking                                        75.490825
# U4   Car                                                  NaN
#      Still                                                NaN
#      Walking                                              NaN
# U5   Still                                         140.068810
#      Walking                                       104.854553
# U6   Bus                                                  NaN
#      Car                                                  NaN
#      Still                                                NaN
#      Train                                                NaN
#      Walking                                              NaN
# U7   Bus                                           165.437782
#      Train                                         193.724706
# U8   Car                                                  NaN
#      Still                                                NaN
# U9   Train                                                NaN
#      Walking                                              NaN
#
#               android.sensor.magnetic_field_uncalibrated#std  \
# user target
# U1   Bus                                            1.371275
#      Car                                            1.690609
#      Still                                          0.744506
#      Train                                          2.277040
#      Walking                                        3.607501
# U10  Car                                            3.388289
#      Still                                          1.272701
#      Walking                                        4.517683
# U11  Car                                            0.963950
# U12  Bus                                            0.796873
#      Car                                            0.932870
#      Still                                          0.323043
#      Train                                          3.332224
#      Walking                                        5.914357
# U13  Car                                            1.106897
# U2   Car                                            1.210127
#      Still                                          0.868547
#      Walking                                        3.147462
# U3   Bus                                            1.559029
#      Train                                          1.882868
#      Walking                                        3.795870
# U4   Car                                                 NaN
#      Still                                               NaN
#      Walking                                             NaN
# U5   Still                                          2.165315
#      Walking                                        4.227786
# U6   Bus                                                 NaN
#      Car                                                 NaN
#      Still                                               NaN
#      Train                                               NaN
#      Walking                                             NaN
# U7   Bus                                            1.570501
#      Train                                          3.734955
# U8   Car                                                 NaN
#      Still                                               NaN
# U9   Train                                               NaN
#      Walking                                             NaN
#
#               android.sensor.orientation#mean  android.sensor.orientation#std  \
# user target
# U1   Bus                           244.263687                       13.957546
#      Car                           178.352256                        8.709023
#      Still                         209.822441                        0.737081
#      Train                         210.081940                        2.180001
#      Walking                       229.788545                       40.640444
# U10  Car                           222.865965                       12.720289
#      Still                         174.710075                        4.026060
#      Walking                       219.941681                       22.614419
# U11  Car                           118.734691                        7.890403
# U12  Bus                           200.895583                       11.331810
#      Car                           216.701967                       12.421247
#      Still                         266.222434                        1.147313
#      Train                         200.877652                        9.095183
#      Walking                       222.508965                       47.566590
# U13  Car                           274.691145                        7.785116
# U2   Car                           125.136743                        3.045390
#      Still                         186.530269                        0.345603
#      Walking                       235.616784                       20.060785
# U3   Bus                           232.968672                        5.570250
#      Train                         164.924656                        0.888389
#      Walking                       208.654426                       35.935475
# U4   Car                           206.710267                        1.696744
#      Still                         311.065574                        0.407376
#      Walking                       210.927217                       35.228603
# U5   Still                         361.407845                        0.152721
#      Walking                       222.118117                       50.017358
# U6   Bus                                  NaN                             NaN
#      Car                                  NaN                             NaN
#      Still                                NaN                             NaN
#      Train                                NaN                             NaN
#      Walking                              NaN                             NaN
# U7   Bus                           280.974902                        0.792703
#      Train                         150.122954                        2.257127
# U8   Car                                  NaN                             NaN
#      Still                                NaN                             NaN
# U9   Train                         135.844023                       14.523800
#      Walking                       249.902691                       37.757646
#
#               android.sensor.rotation_vector#mean  \
# user target
# U1   Bus                                 0.823404
#      Car                                 0.473304
#      Still                               0.973723
#      Train                               0.892410
#      Walking                             0.896692
# U10  Car                                 0.712390
#      Still                               0.645699
#      Walking                             0.836326
# U11  Car                                 0.747199
# U12  Bus                                 0.843823
#      Car                                 0.737641
#      Still                               0.476993
#      Train                               0.701669
#      Walking                             0.821445
# U13  Car                                 0.842628
# U2   Car                                 0.793877
#      Still                               0.718365
#      Walking                             0.854273
# U3   Bus                                 0.949557
#      Train                               0.419194
#      Walking                             0.810071
# U4   Car                                      NaN
#      Still                                    NaN
#      Walking                                  NaN
# U5   Still                               0.645222
#      Walking                             0.831747
# U6   Bus                                      NaN
#      Car                                      NaN
#      Still                                    NaN
#      Train                                    NaN
#      Walking                                  NaN
# U7   Bus                                 0.716313
#      Train                               0.612631
# U8   Car                                      NaN
#      Still                                    NaN
# U9   Train                               0.693971
#      Walking                             0.884430
#
#               android.sensor.rotation_vector#std  new4_std  sound#mean  \
# user target
# U1   Bus                                0.010984  0.350609   89.167125
#      Car                                0.013219  0.276485   89.169925
#      Still                              0.000199  0.020203   79.413998
#      Train                              0.002688  0.085775   88.222562
#      Walking                            0.024921  1.689193   89.513730
# U10  Car                                0.020779  0.533726   69.901688
#      Still                              0.010372  0.139850   57.704151
#      Walking                            0.044490  1.305498   71.650437
# U11  Car                                0.017758  0.233289   82.536167
# U12  Bus                                0.010093  0.315114         NaN
#      Car                                0.009400  0.312115   79.406448
#      Still                              0.004166  0.018097   48.512396
#      Train                              0.014725  0.156255   83.975579
#      Walking                            0.078409  3.242236   86.235182
# U13  Car                                0.006719  0.346818   80.848218
# U2   Car                                0.013266  0.388530   65.523462
#      Still                              0.002958  0.085031   53.462670
#      Walking                            0.017431  1.223875   78.538604
# U3   Bus                                0.007650  0.388616   73.445875
#      Train                              0.007488  0.160107   75.607489
#      Walking                            0.040408  1.359798   56.717053
# U4   Car                                     NaN       NaN   84.328243
#      Still                                   NaN       NaN   51.489825
#      Walking                                 NaN       NaN   65.828516
# U5   Still                              0.043910  0.224815   61.241600
#      Walking                            0.036594  1.849741   83.420966
# U6   Bus                                     NaN       NaN   72.267919
#      Car                                     NaN       NaN   71.014522
#      Still                                   NaN       NaN   39.601176
#      Train                                   NaN       NaN   68.017066
#      Walking                                 NaN       NaN   74.283915
# U7   Bus                                0.008715  0.262233   79.326640
#      Train                              0.007461  0.159261   76.597882
# U8   Car                                     NaN       NaN   69.520780
#      Still                                   NaN       NaN   48.586793
# U9   Train                              0.005934       NaN   68.926143
#      Walking                            0.036865       NaN   78.383604
#
#               speed#std        time
# user target
# U1   Bus            NaN   57.100162
#      Car       0.159099  205.150358
#      Still          NaN  201.248571
#      Train          NaN  170.591346
#      Walking   0.113642  136.613537
# U10  Car       0.075543   59.000000
#      Still     0.003440  181.793451
#      Walking   0.003575   14.675676
# U11  Car       0.733853   80.107784
# U12  Bus       0.217704   26.154762
#      Car       0.775725   67.085271
#      Still     0.000000  169.000000
#      Train     0.214846   28.691781
#      Walking   0.093849   24.923810
# U13  Car       0.518535   68.755556
# U2   Car            NaN   24.812500
#      Still          NaN   24.133333
#      Walking   0.007071   56.640000
# U3   Bus            NaN   33.518293
#      Train          NaN   32.727273
#      Walking   0.000000  184.650407
# U4   Car            NaN   41.333333
#      Still          NaN   34.500000
#      Walking        NaN   67.595092
# U5   Still     0.000000    9.333333
#      Walking   0.010134   31.818182
# U6   Bus       0.718155   42.012346
#      Car       0.461157   45.333333
#      Still          NaN   73.215686
#      Train     0.323722   44.166667
#      Walking   0.000000   27.888889
# U7   Bus       0.092852   75.500000
#      Train          NaN   99.262948
# U8   Car       0.085365  294.609626
#      Still     0.014235   64.629630
# U9   Train          NaN   91.690476
#      Walking        NaN   51.648649

# %%
b = df1_drop_by_corr1.copy()
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5893 entries, 0 to 5892
# Data columns (total 17 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   time                                             5893 non-null   float64
#  1   activityrecognition#1                            5893 non-null   float64
#  2   android.sensor.game_rotation_vector#std          5093 non-null   float64
#  3   android.sensor.gravity#std                       5356 non-null   float64
#  4   android.sensor.magnetic_field#mean               5400 non-null   float64
#  5   android.sensor.magnetic_field#std                5383 non-null   float64
#  6   android.sensor.magnetic_field_uncalibrated#mean  5094 non-null   float64
#  7   android.sensor.magnetic_field_uncalibrated#std   5087 non-null   float64
#  8   android.sensor.orientation#mean                  5396 non-null   float64
#  9   android.sensor.orientation#std                   5373 non-null   float64
#  10  android.sensor.rotation_vector#mean              5172 non-null   float64
#  11  android.sensor.rotation_vector#std               5163 non-null   float64
#  12  sound#mean                                       4899 non-null   float64
#  13  speed#std                                        1318 non-null   float64
#  14  target                                           5893 non-null   object
#  15  user                                             5893 non-null   object
#  16  new4_std                                         5065 non-null   float64
# dtypes: float64(15), object(2)
# memory usage: 957.7+ KB

# %%
df1_drop_by_corr[['android.sensor.accelerometer#std','android.sensor.linear_acceleration#std']]
# Out:
#       android.sensor.accelerometer#std  android.sensor.linear_acceleration#std
# 0                             0.014626                                0.011045
# 1                             1.775944                                0.278730
# 2                             0.011199                                0.011881
# 3                             0.862553                                0.920077
# 4                             0.504117                                1.122225
# ...                                ...                                     ...
# 5888                          3.373972                                0.982225
# 5889                          0.665529                                0.130453
# 5890                          0.017633                                0.008937
# 5891                          0.013485                                0.026978
# 5892                          4.745098                                1.057284
#
# [5893 rows x 2 columns]

# %%
df1_drop_by_corr['accelerometer#std_tion#std'] = df1_drop_by_corr.apply(lambda a: 
(a['android.sensor.accelerometer#std']+a['android.sensor.linear_acceleration#std'])/2, axis=1)

# %%
df1_drop_by_corr[['android.sensor.gyroscope#std',
 'android.sensor.gyroscope_uncalibrated#std']]
# Out:
#       android.sensor.gyroscope#std  android.sensor.gyroscope_uncalibrated#std
# 0                         0.000737                                   0.000982
# 1                         0.020290                                   0.018629
# 2                         0.000713                                   0.000876
# 3                         0.010553                                   0.018037
# 4                         0.098819                                   0.083175
# ...                            ...                                        ...
# 5888                      0.389385                                   0.164709
# 5889                      0.005964                                   0.006740
# 5890                      0.000904                                   0.001057
# 5891                      0.001301                                   0.000402
# 5892                      0.882147                                   0.710473
#
# [5893 rows x 2 columns]

# %%
df1_drop_by_corr['gyrscope_uncalibrated#std'] = df1_drop_by_corr.apply(lambda a:
(a['android.sensor.gyroscope#std']+a['android.sensor.gyroscope_uncalibrated#std'])/2, axis=1)

# %%
df1_drop_by_corr['new4_std'] = df1_drop_by_corr.apply(lambda a:
(a['gyrscope_uncalibrated#std'] + a['accelerometer#std_tion#std'])/2, axis=1)

# %%
fig, ax = plt.subplots(figsize=(20,20))
ax = sns.heatmap(df1_drop_by_corr1.corr(),vmin=-1, vmax=1, annot=True)

# %%
df1_drop_by_corr1.iloc[:, :].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5893 entries, 0 to 5892
# Data columns (total 17 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   time                                             5893 non-null   float64
#  1   activityrecognition#1                            5893 non-null   float64
#  2   android.sensor.game_rotation_vector#std          5093 non-null   float64
#  3   android.sensor.gravity#std                       5356 non-null   float64
#  4   android.sensor.magnetic_field#mean               5400 non-null   float64
#  5   android.sensor.magnetic_field#std                5383 non-null   float64
#  6   android.sensor.magnetic_field_uncalibrated#mean  5094 non-null   float64
#  7   android.sensor.magnetic_field_uncalibrated#std   5087 non-null   float64
#  8   android.sensor.orientation#mean                  5396 non-null   float64
#  9   android.sensor.orientation#std                   5373 non-null   float64
#  10  android.sensor.rotation_vector#mean              5172 non-null   float64
#  11  android.sensor.rotation_vector#std               5163 non-null   float64
#  12  sound#mean                                       4899 non-null   float64
#  13  speed#std                                        1318 non-null   float64
#  14  target                                           5893 non-null   object
#  15  user                                             5893 non-null   object
#  16  new4_std                                         5065 non-null   float64
# dtypes: float64(15), object(2)
# memory usage: 957.7+ KB

# %%
df1_drop_by_corr[['android.sensor.accelerometer#std','android.sensor.linear_acceleration#std']]
df1_drop_by_corr['accelerometer#std_tion#std'] = df1_drop_by_corr.apply(lambda a: 
(a['android.sensor.accelerometer#std']+a['android.sensor.linear_acceleration#std'])/2, axis=1)
# data['t1_t2'] = data.apply(lambda row: (row['t1']+row['t2'])/2, axis=1)

# %%
df1_drop_by_corr['accelerometer#std_tion#std']
# Out:
# 0       0.012835
# 1       1.027337
# 2       0.011540
# 3       0.891315
# 4       0.813171
#           ...
# 5888    2.178098
# 5889    0.397991
# 5890    0.013285
# 5891    0.020231
# 5892    2.901191
# Name: accelerometer#std_tion#std, Length: 5893, dtype: float64

# %%
a = df1_drop_by_corr1.columns.to_list()
a
# Out:
# ['time',
#  'activityrecognition#1',
#  'android.sensor.game_rotation_vector#mean',
#  'android.sensor.game_rotation_vector#std',
#  'android.sensor.gravity#mean',
#  'android.sensor.gravity#std',
#  'android.sensor.light#std',
#  'android.sensor.magnetic_field#mean',
#  'android.sensor.magnetic_field#std',
#  'android.sensor.magnetic_field_uncalibrated#mean',
#  'android.sensor.magnetic_field_uncalibrated#std',
#  'android.sensor.orientation#mean',
#  'android.sensor.orientation#std',
#  'android.sensor.pressure#std',
#  'android.sensor.proximity#mean',
#  'android.sensor.proximity#std',
#  'android.sensor.rotation_vector#mean',
#  'android.sensor.rotation_vector#std',
#  'android.sensor.step_counter#mean',
#  'android.sensor.step_counter#std',
#  'sound#mean',
#  'sound#std',
#  'speed#mean',
#  'speed#std',
#  'target',
#  'user',
#  'new4_std']

# %%
from sklearn.preprocessing import OrdinalEncoder

enc = OrdinalEncoder()

df_nec = df.copy()
cat = df1_drop_by_corr1[['user', 'target']]
res=enc.fit_transform(cat)
res
df1_drop_by_corr1

    # tree_prepro = compose.ColumnTransformer(transformers=[
    #     ('num', num_4_treeModels, num_vars),
    #     ('cat', cat_4_treeModels, cat_vars),
    # ], remainder='drop') # Drop other vars not specified in num_vars or cat_vars
# Out:
#        time  activityrecognition#1  android.sensor.game_rotation_vector#std  \
# 0      78.0                  100.0                                 0.000119
# 1     145.0                  100.0                                 0.000030
# 2     150.0                  100.0                                 0.000004
# 3     105.0                   77.0                                 0.003451
# 4      77.0                  100.0                                 0.064792
# ...     ...                    ...                                      ...
# 5888    4.0                  100.0                                 0.007186
# 5889   32.0                   10.0                                 0.000331
# 5890   86.0                  100.0                                 0.000211
# 5891  199.0                  100.0                                 0.000002
# 5892   55.0                  100.0                                 0.019459
#
#       android.sensor.gravity#std  android.sensor.magnetic_field#mean  \
# 0                   4.780692e-07                           57.099638
# 1                   6.474977e-07                           29.351288
# 2                   2.821568e-07                           29.904927
# 3                   2.120564e-06                           37.836471
# 4                   2.644430e-07                           78.375718
# ...                          ...                                 ...
# 5888                2.229298e-07                           28.551588
# 5889                8.174791e-07                           40.665641
# 5890                4.292944e-07                           57.026001
# 5891                2.931281e-05                           62.277008
# 5892                3.594931e-07                           43.983419
#
#       android.sensor.magnetic_field#std  \
# 0                              0.177549
# 1                              0.921547
# 2                              0.130851
# 3                              0.439461
# 4                              1.104361
# ...                                 ...
# 5888                           0.381842
# 5889                           1.755636
# 5890                           0.209266
# 5891                           0.636157
# 5892                           1.073626
#
#       android.sensor.magnetic_field_uncalibrated#mean  \
# 0                                           51.363566
# 1                                           82.767760
# 2                                           55.695716
# 3                                           95.743821
# 4                                          157.429218
# ...                                               ...
# 5888                                        56.502261
# 5889                                        85.122017
# 5890                                        51.317797
# 5891                                       270.495205
# 5892                                       149.048369
#
#       android.sensor.magnetic_field_uncalibrated#std  \
# 0                                           0.080899
# 1                                           0.506105
# 2                                           0.128945
# 3                                           0.112446
# 4                                           0.895633
# ...                                              ...
# 5888                                       23.640120
# 5889                                        4.265621
# 5890                                        0.074212
# 5891                                        0.235700
# 5892                                        0.054675
#
#       android.sensor.orientation#mean  android.sensor.orientation#std  \
# 0                          354.286933                        0.245676
# 1                          332.695577                        1.705816
# 2                           74.752653                        0.413704
# 3                          373.556039                        8.870011
# 4                          193.201458                      181.729455
# ...                               ...                             ...
# 5888                       198.025171                        0.858121
# 5889                        35.427524                        1.794702
# 5890                       354.182815                        0.307487
# 5891                        32.077433                        0.000209
# 5892                       260.716040                      128.622821
#
#       android.sensor.rotation_vector#mean  android.sensor.rotation_vector#std  \
# 0                                0.050413                            0.002109
# 1                                0.999981                            0.000026
# 2                                0.610456                            0.011312
# 3                                0.998112                            0.002788
# 4                                0.322242                            0.025608
# ...                                   ...                                 ...
# 5888                             0.932682                            0.008767
# 5889                             0.295905                            0.018447
# 5890                             0.051333                            0.002659
# 5891                             0.276348                            0.000005
# 5892                             0.990902                            0.003996
#
#       sound#mean  speed#std   target user  new4_std
# 0            NaN   0.000000    Still  U12  0.006847
# 1      89.200210   0.628595      Car  U12  0.523398
# 2            NaN   0.000000    Still  U12  0.006167
# 3      87.470377   0.628595      Car  U12  0.452805
# 4      89.770732        NaN      Car   U1  0.452084
# ...          ...        ...      ...  ...       ...
# 5888         NaN        NaN  Walking   U2  1.227573
# 5889         NaN        NaN    Train   U3  0.202172
# 5890         NaN   0.000000    Still  U12  0.007133
# 5891         NaN        NaN    Still  U10  0.010541
# 5892   89.712441        NaN  Walking   U1  1.848750
#
# [5893 rows x 17 columns]

# %%
# df1[df1['android.sensor.gyroscope_uncalibrated#min'].isna()][['target','user']]

# %%
df[df['target'] == 'Car']['speed#std'].describe()
# Out:
# count    509.000000
# mean       0.440738
# std        0.609495
# min        0.000000
# 25%        0.012442
# 50%        0.204414
# 75%        0.600782
# max        3.842801
# Name: speed#std, dtype: float64

# %%
df1.corr
# Out:
# <bound method DataFrame.corr of          id   time  activityrecognition#1  android.sensor.accelerometer#mean  \
# 0     16170   78.0                  100.0                           9.811476
# 1     15871  145.0                  100.0                           9.939207
# 2     16811  150.0                  100.0                           9.827178
# 3     15831  105.0                   77.0                           9.673039
# 4       876   77.0                  100.0                           9.993466
# ...     ...    ...                    ...                                ...
# 5888  14125    4.0                  100.0                          10.066610
# 5889  19582   32.0                   10.0                           9.964271
# 5890  16178   86.0                  100.0                           9.812893
# 5891  10973  199.0                  100.0                           9.831144
# 5892   8278   55.0                  100.0                          11.051009
#
#       android.sensor.accelerometer#min  android.sensor.accelerometer#max  \
# 0                             9.758895                          9.849411
# 1                             7.707437                         17.146631
# 2                             9.804817                          9.849262
# 3                             7.659674                         12.304298
# 4                             8.965621                         10.891645
# ...                                ...                               ...
# 5888                          4.564648                         13.414389
# 5889                          8.768007                         11.454213
# 5890                          9.772881                          9.862587
# 5891                          9.807347                          9.874450
# 5892                          5.203285                         19.921068
#
#       android.sensor.accelerometer#std  \
# 0                             0.014626
# 1                             1.775944
# 2                             0.011199
# 3                             0.862553
# 4                             0.504117
# ...                                ...
# 5888                          3.373972
# 5889                          0.665529
# 5890                          0.017633
# 5891                          0.013485
# 5892                          4.745098
#
#       android.sensor.game_rotation_vector#mean  \
# 0                                     0.029340
# 1                                     0.999925
# 2                                     0.665215
# 3                                     0.996221
# 4                                     0.563792
# ...                                        ...
# 5888                                  0.986319
# 5889                                  0.648602
# 5890                                  0.024392
# 5891                                  0.481212
# 5892                                  0.919815
#
#       android.sensor.game_rotation_vector#min  \
# 0                                    0.029014
# 1                                    0.999903
# 2                                    0.665213
# 3                                    0.993781
# 4                                    0.521799
# ...                                       ...
# 5888                                 0.974523
# 5889                                 0.648343
# 5890                                 0.024081
# 5891                                 0.481209
# 5892                                 0.892571
#
#       android.sensor.game_rotation_vector#max  ...  sound#mean  sound#min  \
# 0                                    0.029526  ...         NaN        NaN
# 1                                    0.999946  ...   89.200210  89.065143
# 2                                    0.665218  ...         NaN        NaN
# 3                                    0.998661  ...   87.470377  87.470377
# 4                                    0.672664  ...   89.770732  89.770732
# ...                                       ...  ...         ...        ...
# 5888                                 0.992084  ...         NaN        NaN
# 5889                                 0.648974  ...         NaN        NaN
# 5890                                 0.024696  ...         NaN        NaN
# 5891                                 0.481216  ...         NaN        NaN
# 5892                                 0.944020  ...   89.712441  89.712441
#
#       sound#max  sound#std  speed#mean  speed#min  speed#max  speed#std  \
# 0           NaN        NaN    0.000000   0.000000   0.000000   0.000000
# 1     89.335277   0.191013   16.539349  16.539349  16.539349   0.628595
# 2           NaN        NaN    0.000000   0.000000   0.000000   0.000000
# 3     87.470377   2.284186   17.739895  17.739895  17.739895   0.628595
# 4     89.770732   0.006389    9.000000   9.000000   9.000000        NaN
# ...         ...        ...         ...        ...        ...        ...
# 5888        NaN        NaN         NaN        NaN        NaN        NaN
# 5889        NaN        NaN   31.960054  31.960054  31.960054        NaN
# 5890        NaN        NaN    0.000000   0.000000   0.000000   0.000000
# 5891        NaN        NaN    1.090415   1.090415   1.090415        NaN
# 5892  89.712441   0.006400    0.750000   0.750000   0.750000        NaN
#
#        target  user
# 0       Still   U12
# 1         Car   U12
# 2       Still   U12
# 3         Car   U12
# 4         Car    U1
# ...       ...   ...
# 5888  Walking    U2
# 5889    Train    U3
# 5890    Still   U12
# 5891    Still   U10
# 5892  Walking    U1
#
# [5893 rows x 69 columns]>

# %%
last_data = df1_drop_by_corr2.copy()
last_data.to_csv('last.csv', index=False)

# %%
last_data.columns
# Out:
# Index(['time', 'activityrecognition#1', 'android.sensor.gravity#std',
#        'android.sensor.magnetic_field#std',
#        'android.sensor.magnetic_field_uncalibrated#std',
#        'android.sensor.orientation#mean', 'android.sensor.orientation#std',
#        'android.sensor.rotation_vector#mean', 'sound#mean', 'target', 'user',
#        'new4_std', 'game_rot_vec_std', 'mag_field_mean'],
#       dtype='object')

# %%
last_ = pd.pivot_table(last_data ,index=['target'])
last_
# Out:
#          activityrecognition#1  android.sensor.gravity#std  \
# target
# Bus                  80.381818                7.385717e-07
# Car                  89.001364                3.352951e-06
# Still                96.863014                1.010076e-05
# Train                84.192872                9.587758e-07
# Walking              86.556098                9.770787e-07
#
#          android.sensor.magnetic_field#std  \
# target
# Bus                               1.419693
# Car                               1.385068
# Still                             0.876929
# Train                             3.046042
# Walking                           2.211862
#
#          android.sensor.magnetic_field_uncalibrated#std  \
# target
# Bus                                            1.406447
# Car                                            1.570811
# Still                                          0.988955
# Train                                          2.682449
# Walking                                        3.639898
#
#          android.sensor.orientation#mean  android.sensor.orientation#std  \
# target
# Bus                           250.167078                       10.757766
# Car                           206.752647                       10.098282
# Still                         199.372956                        2.148300
# Train                         195.382262                        2.752659
# Walking                       227.195448                       33.577384
#
#          android.sensor.rotation_vector#mean  game_rot_vec_std  \
# target
# Bus                                 0.825104          0.010241
# Car                                 0.667548          0.013462
# Still                               0.855002          0.005534
# Train                               0.799933          0.004102
# Walking                             0.870256          0.025050
#
#          mag_field_mean  new4_std  sound#mean        time
# target
# Bus           90.306039  0.341326   85.228565   58.314773
# Car          118.765272  0.298623   83.350040  131.729877
# Still        111.133537  0.083290   67.560388  179.358904
# Train        109.498613  0.110067   84.657388  140.631027
# Walking       79.277422  1.531544   82.292695  119.407317

# %%
last_ = pd.pivot_table(last_data, index=['user', 'target'])
last_
# Out:
#               activityrecognition#1  android.sensor.gravity#std  \
# user target
# U1   Bus                  76.850329                3.843354e-07
#      Car                  90.371951                3.119045e-07
#      Still               100.000000                2.804420e-07
#      Train                81.309295                3.670707e-07
#      Walking              91.430131                4.066247e-07
# U10  Car                  77.083333                2.392420e-05
#      Still                95.480892                2.304793e-05
#      Walking              86.500000                2.341777e-05
# U11  Car                  92.520661                2.174409e-06
# U12  Car                  89.688000                2.720514e-06
#      Still               100.000000                3.908436e-07
#      Train                97.416667                4.071872e-06
#      Walking             100.000000                6.149353e-06
# U13  Car                  84.107143                3.730466e-06
# U2   Car                 100.000000                2.286167e-07
#      Still                71.551724                3.766984e-07
#      Walking              93.369863                3.597817e-07
# U3   Bus                  89.963504                7.064537e-07
#      Train                95.370370                3.420791e-07
#      Walking              43.453608                5.702849e-07
# U5   Still                77.000000                6.873894e-06
#      Walking             100.000000                5.310202e-06
# U7   Bus                  86.562963                2.366541e-06
#      Train                87.090535                1.778072e-06
#
#               android.sensor.magnetic_field#std  \
# user target
# U1   Bus                               1.412912
#      Car                               1.893673
#      Still                             0.712234
#      Train                             3.335478
#      Walking                           1.875091
# U10  Car                               2.030532
#      Still                             1.143791
#      Walking                           2.665886
# U11  Car                               0.849952
# U12  Car                               0.896075
#      Still                             0.381572
#      Train                             2.264806
#      Walking                           2.016534
# U13  Car                               0.495527
# U2   Car                               1.054709
#      Still                             0.418776
#      Walking                           1.879871
# U3   Bus                               1.865749
#      Train                             2.663638
#      Walking                           4.411580
# U5   Still                             3.113139
#      Walking                           3.359038
# U7   Bus                               0.997563
#      Train                             2.538186
#
#               android.sensor.magnetic_field_uncalibrated#std  \
# user target
# U1   Bus                                            1.342180
#      Car                                            1.795185
#      Still                                          0.744506
#      Train                                          2.277040
#      Walking                                        3.607501
# U10  Car                                            3.796736
#      Still                                          1.318309
#      Walking                                        4.165742
# U11  Car                                            0.992355
# U12  Car                                            0.931378
#      Still                                          0.476339
#      Train                                          3.129707
#      Walking                                        7.140728
# U13  Car                                            0.939532
# U2   Car                                            1.290803
#      Still                                          0.865594
#      Walking                                        3.021703
# U3   Bus                                            1.469828
#      Train                                          1.686486
#      Walking                                        4.226771
# U5   Still                                          2.818661
#      Walking                                        4.227786
# U7   Bus                                            1.631566
#      Train                                          3.723729
#
#               android.sensor.orientation#mean  android.sensor.orientation#std  \
# user target
# U1   Bus                           244.997229                       14.102114
#      Car                           212.685807                       10.432317
#      Still                         209.822441                        0.737081
#      Train                         210.081940                        2.180001
#      Walking                       229.788545                       40.640444
# U10  Car                           230.321804                       13.718198
#      Still                         188.356828                        4.035963
#      Walking                       174.967670                       24.295813
# U11  Car                           132.479109                        8.116093
# U12  Car                           219.228631                       11.508958
#      Still                         194.602652                        0.926998
#      Train                         221.605861                       11.816610
#      Walking                       200.310637                       38.629156
# U13  Car                           269.468934                        8.191628
# U2   Car                           126.699731                        3.225660
#      Still                         187.131803                        0.353040
#      Walking                       235.478190                       20.349883
# U3   Bus                           236.937777                        5.735281
#      Train                         206.969840                        0.582935
#      Walking                       209.663241                       28.178308
# U5   Still                         361.222370                        0.152721
#      Walking                       222.118117                       50.017358
# U7   Bus                           286.875833                        0.792703
#      Train                         149.872470                        2.226256
#
#               android.sensor.rotation_vector#mean  game_rot_vec_std  \
# user target
# U1   Bus                                 0.825248          0.010572
#      Car                                 0.509635          0.013796
#      Still                               0.973723          0.000266
#      Train                               0.892410          0.001771
#      Walking                             0.896692          0.025925
# U10  Car                                 0.833088          0.021103
#      Still                               0.722474          0.011879
#      Walking                             0.801097          0.079692
# U11  Car                                 0.793567          0.013132
# U12  Car                                 0.735297          0.012064
#      Still                               0.991523          0.000493
#      Train                               0.769716          0.008007
#      Walking                             0.838363          0.039932
# U13  Car                                 0.861388          0.008501
# U2   Car                                 0.791779          0.017696
#      Still                               0.709004          0.003314
#      Walking                             0.852602          0.014060
# U3   Bus                                 0.948446          0.009141
#      Train                               0.447214          0.002450
#      Walking                             0.805776          0.034422
# U5   Still                               0.613557          0.051859
#      Walking                             0.831747          0.034039
# U7   Bus                                 0.699285          0.009869
#      Train                               0.609114          0.009309
#
#               mag_field_mean  new4_std  sound#mean        time
# user target
# U1   Bus           89.215072  0.347257   89.175744   58.044408
#      Car          136.604608  0.279823   89.169925  201.317073
#      Still         88.733260  0.020203   79.413998  201.248571
#      Train         98.477147  0.085775   88.222562  170.591346
#      Walking       89.651441  1.689193   89.513730  136.613537
# U10  Car          165.719973  0.405197   68.969802   83.883333
#      Still        148.405742  0.160736   57.847299  179.802548
#      Walking      162.849710  1.081286   72.520904   10.833333
# U11  Car           54.366479  0.239303   82.536167   85.504132
# U12  Car           59.172657  0.311377   79.694108   69.112000
#      Still         34.055743  0.006553   48.512396   94.028571
#      Train         66.617410  0.148054   84.090120   32.266667
#      Walking       66.728330  2.304054   86.587748   23.478261
# U13  Car          207.584350  0.346818   80.692429   72.833333
# U2   Car           59.561553  0.385784   65.523462   26.000000
#      Still         68.783616  0.087519   53.462670   24.758621
#      Walking       64.128645  1.215958   78.546884   58.077626
# U3   Bus           79.322472  0.412373   73.546477   37.160584
#      Train         62.004908  0.136050   75.607489   33.518519
#      Walking       56.854143  1.336135   56.717053  222.742268
# U5   Still        142.381169  0.245990   55.890332   14.000000
#      Walking       81.741173  1.849741   83.420966   31.818182
# U7   Bus          106.365717  0.242517   79.306798   81.000000
#      Train        153.665680  0.160181   76.647982  102.353909

# %%
df.head(50)
# Out:
#        id   time  activityrecognition#0  activityrecognition#1  \
# 0   16170   78.0                    NaN                  100.0
# 1   15871  145.0                    NaN                  100.0
# 2   16811  150.0                    NaN                  100.0
# 3   15831  105.0                    NaN                   77.0
# 4     876   77.0                    NaN                  100.0
# 5   13480  559.0                    NaN                  100.0
# 6   18786   41.0                    NaN                  100.0
# 7   15268   20.0                    NaN                  100.0
# 8     343   35.0                    NaN                  100.0
# 9    4650   27.0                    NaN                   69.0
# 10  12177  234.0                    NaN                  100.0
# 11   4758  135.0                    NaN                   23.0
# 12   9972   11.0                    NaN                  100.0
# 13   1937  563.0                    NaN                  100.0
# 14  18258    7.0                    NaN                  100.0
# 15   3304   30.0                    NaN                  100.0
# 16  11660   32.0                    NaN                   54.0
# 17   2324   37.0                    NaN                  100.0
# 18  18169   20.0                    NaN                  100.0
# 19   3498  224.0                    NaN                  100.0
# 20   7528  159.0                    NaN                   83.0
# 21   1204  238.0                    NaN                  100.0
# 22  16735   74.0                    NaN                  100.0
# 23  16871   40.0                    NaN                  100.0
# 24  11656   28.0                    NaN                   54.0
# 25  18808   63.0                    NaN                  100.0
# 26   6597   70.0                    NaN                  100.0
# 27    432   41.0                    NaN                  100.0
# 28  11234   75.0                    NaN                   92.0
# 29  22001   19.0                    NaN                  100.0
# 30   1869  495.0                    NaN                  100.0
# 31   8219  517.0                    NaN                   51.0
# 32  20964   46.0                    NaN                   75.0
# 33  19919  260.0                    NaN                    5.0
# 34  13525  604.0                    NaN                  100.0
# 35  11663   35.0                    NaN                   54.0
# 36  18321   70.0                    NaN                   85.0
# 37    416   25.0                    NaN                  100.0
# 38   8292   69.0                    NaN                  100.0
# 39  20740  156.0                    NaN                   85.0
# 40  21425   52.0                    NaN                   46.0
# 41  21275   77.0                    NaN                  100.0
# 42  12212  269.0                    NaN                  100.0
# 43    223   39.0                    NaN                   15.0
# 44  17307    7.0                    NaN                   90.0
# 45  20513  117.0                    NaN                  100.0
# 46   2398  111.0                    NaN                   85.0
# 47  18422   25.0                    NaN                  100.0
# 48  13214  293.0                    NaN                  100.0
# 49  14599   17.0                    NaN                  100.0
#
#     android.sensor.accelerometer#mean  android.sensor.accelerometer#min  \
# 0                            9.811476                          9.758895
# 1                            9.939207                          7.707437
# 2                            9.827178                          9.804817
# 3                            9.673039                          7.659674
# 4                            9.993466                          8.965621
# 5                            9.330482                          9.149029
# 6                            9.789771                          9.758751
# 7                            9.906011                          6.431646
# 8                            9.639711                          8.996134
# 9                            9.602109                          9.014786
# 10                           9.864565                          9.554663
# 11                           9.446527                          8.901048
# 12                           9.365727                          3.758712
# 13                           9.932078                          9.608102
# 14                           9.826201                          8.522106
# 15                          10.180867                         10.160483
# 16                           9.709153                          9.183983
# 17                           9.528492                          9.051952
# 18                          10.098494                          4.184305
# 19                          10.192464                         10.085247
# 20                           9.899484                          6.762555
# 21                           9.764914                          8.099912
# 22                           9.840980                          9.814482
# 23                           9.821242                          9.765504
# 24                           9.730397                          9.050716
# 25                           9.714570                          9.118590
# 26                           8.534807                          3.979284
# 27                          10.025645                          9.754751
# 28                           9.764391                          9.312685
# 29                          10.412105                          5.053769
# 30                           9.935582                          9.247339
# 31                          10.072686                         10.006071
# 32                           9.681337                          8.906632
# 33                          11.068949                          9.764513
# 34                           9.690549                          9.654373
# 35                           9.730385                          9.322400
# 36                           9.807534                          7.432049
# 37                           9.395328                          6.341008
# 38                           9.668010                          4.853963
# 39                           9.857333                          9.419976
# 40                           9.774353                          8.592088
# 41                          10.052635                          8.396031
# 42                           9.844261                          9.651531
# 43                           9.665247                          8.730821
# 44                           9.735955                          8.653051
# 45                           9.770010                          9.314642
# 46                           9.594837                          8.848495
# 47                           9.051317                          5.257488
# 48                           9.707512                          9.379520
# 49                          10.413624                          3.324387
#
#     android.sensor.accelerometer#max  android.sensor.accelerometer#std  \
# 0                           9.849411                          0.014626
# 1                          17.146631                          1.775944
# 2                           9.849262                          0.011199
# 3                          12.304298                          0.862553
# 4                          10.891645                          0.504117
# 5                           9.520044                          0.103857
# 6                           9.816197                          0.013489
# 7                          14.202603                          1.044684
# 8                          10.027802                          0.255053
# 9                          10.068528                          0.267791
# 10                         10.343346                          0.114261
# 11                         10.013365                          0.317446
# 12                         13.724810                          2.508427
# 13                         10.204232                          0.145972
# 14                         11.364474                          0.389263
# 15                         10.198376                          0.013581
# 16                         10.573025                          0.298172
# 17                          9.987014                          0.312274
# 18                         20.965369                          4.496926
# 19                         10.251119                          0.054377
# 20                         15.594669                          2.839778
# 21                         11.178526                          0.739418
# 22                          9.867058                          0.013051
# 23                          9.880349                          0.023715
# 24                         11.003434                          0.295131
# 25                         10.103023                          0.254989
# 26                         14.539783                          3.697971
# 27                         10.668525                          0.272660
# 28                         10.014071                          0.127722
# 29                         18.951475                          3.328673
# 30                         10.486087                          0.272532
# 31                         10.139301                          0.094208
# 32                         10.551185                          0.412847
# 33                         14.028126                          1.283204
# 34                          9.729916                          0.017070
# 35                         10.221042                          0.136866
# 36                         12.136723                          0.782634
# 37                         10.908684                          1.242317
# 38                         15.966458                          3.597505
# 39                         10.540381                          0.250972
# 40                         11.842069                          0.607953
# 41                         12.568080                          0.843316
# 42                         10.001332                          0.068007
# 43                         10.944207                          0.496075
# 44                         10.823420                          0.340394
# 45                         10.624079                          0.404480
# 46                         10.801026                          0.599259
# 47                         10.588503                          1.344355
# 48                          9.970652                          0.178203
# 49                         14.608536                          4.031835
#
#     android.sensor.game_rotation_vector#mean  \
# 0                                   0.029340
# 1                                   0.999925
# 2                                   0.665215
# 3                                   0.996221
# 4                                   0.563792
# 5                                        NaN
# 6                                   0.295890
# 7                                   0.700760
# 8                                   0.969450
# 9                                   0.896536
# 10                                  0.783412
# 11                                  0.998856
# 12                                  0.693536
# 13                                  0.301757
# 14                                  0.414550
# 15                                  0.995053
# 16                                  0.779379
# 17                                  0.780514
# 18                                  0.813854
# 19                                  0.991041
# 20                                  0.921806
# 21                                  0.997470
# 22                                  0.260766
# 23                                  0.603619
# 24                                  0.723544
# 25                                  0.356097
# 26                                  0.983593
# 27                                  0.900079
# 28                                  0.656992
# 29                                       NaN
# 30                                  0.358190
# 31                                  0.770168
# 32                                  0.939598
# 33                                  0.943836
# 34                                       NaN
# 35                                  0.796486
# 36                                  0.684224
# 37                                  0.944919
# 38                                  0.766798
# 39                                  0.632117
# 40                                       NaN
# 41                                       NaN
# 42                                  0.486841
# 43                                  0.630156
# 44                                  0.036694
# 45                                  0.570064
# 46                                  0.788817
# 47                                  0.448834
# 48                                       NaN
# 49                                  0.995565
#
#     android.sensor.game_rotation_vector#min  ...  sound#mean  sound#min  \
# 0                                  0.029014  ...         NaN        NaN
# 1                                  0.999903  ...   89.200210  89.065143
# 2                                  0.665213  ...         NaN        NaN
# 3                                  0.993781  ...   87.470377  87.470377
# 4                                  0.521799  ...   89.770732  89.770732
# 5                                       NaN  ...   57.361127  57.361127
# 6                                  0.295890  ...   65.158369  65.158369
# 7                                  0.686746  ...         NaN        NaN
# 8                                  0.965963  ...   89.808441  89.808441
# 9                                  0.894287  ...   89.815738  89.815738
# 10                                 0.779935  ...   70.570621  70.570621
# 11                                 0.998772  ...   89.792139  89.792139
# 12                                 0.693536  ...   85.031304  85.031304
# 13                                 0.299380  ...   89.763785  89.708466
# 14                                 0.397586  ...   78.506242  78.506242
# 15                                 0.995039  ...   80.620894  80.620894
# 16                                 0.763049  ...   84.474928  84.418890
# 17                                 0.773229  ...   89.754360  89.754360
# 18                                 0.813854  ...         NaN        NaN
# 19                                 0.986503  ...   69.349202  69.349202
# 20                                 0.909580  ...   89.795796  89.795796
# 21                                 0.997162  ...         NaN        NaN
# 22                                 0.260766  ...         NaN        NaN
# 23                                 0.603501  ...         NaN        NaN
# 24                                 0.715147  ...   84.133190  83.709710
# 25                                 0.356097  ...   69.725775  69.725775
# 26                                 0.965434  ...   89.759727  89.759727
# 27                                 0.890404  ...   88.982119  88.258614
# 28                                 0.610942  ...   57.650491  57.650491
# 29                                      NaN  ...   72.397556  67.298521
# 30                                 0.352502  ...   86.667333  86.667333
# 31                                 0.758804  ...   89.765923  89.750403
# 32                                 0.939292  ...   82.261478  82.261478
# 33                                 0.936799  ...   77.064227  77.064227
# 34                                      NaN  ...   49.307657  49.307657
# 35                                 0.787416  ...   84.382327  84.270886
# 36                                 0.684224  ...   85.894173  85.894173
# 37                                 0.936083  ...   89.776653  89.776653
# 38                                 0.692695  ...   89.688844  89.688844
# 39                                 0.564461  ...   76.334104  76.334104
# 40                                      NaN  ...   72.582073  72.582073
# 41                                      NaN  ...   76.377708  76.377708
# 42                                 0.485190  ...   82.874656  82.874656
# 43                                 0.627230  ...   89.785948  89.785948
# 44                                 0.026793  ...         NaN        NaN
# 45                                 0.569829  ...         NaN        NaN
# 46                                 0.784369  ...   89.766783  89.766783
# 47                                 0.418437  ...   76.074463  64.464725
# 48                                      NaN  ...   81.151801  81.151801
# 49                                 0.995565  ...   77.221125  77.221125
#
#     sound#max  sound#std  speed#mean  speed#min  speed#max  speed#std  \
# 0         NaN        NaN    0.000000   0.000000   0.000000   0.000000
# 1   89.335277   0.191013   16.539349  16.539349  16.539349   0.628595
# 2         NaN        NaN    0.000000   0.000000   0.000000   0.000000
# 3   87.470377   2.284186   17.739895  17.739895  17.739895   0.628595
# 4   89.770732   0.006389    9.000000   9.000000   9.000000        NaN
# 5   57.361127   1.006611    0.000000   0.000000   0.000000   0.000000
# 6   65.158369        NaN         NaN        NaN        NaN        NaN
# 7         NaN        NaN    7.797239   7.587349   8.146695   0.304673
# 8   89.808441   0.010171    4.750000   4.750000   4.750000        NaN
# 9   89.815738   0.004995         NaN        NaN        NaN        NaN
# 10  70.570621   7.974878    0.000000   0.000000   0.000000        NaN
# 11  89.792139   0.037446         NaN        NaN        NaN        NaN
# 12  85.031304   7.035722    6.965024   6.965024   6.965024   0.204414
# 13  89.819105   0.078234    9.500000   9.500000   9.500000        NaN
# 14  78.506242   0.727791    2.647271   2.647271   2.647271   0.463508
# 15  80.620894        NaN         NaN        NaN        NaN        NaN
# 16  84.530967   0.079251    0.993526   0.993526   0.993526        NaN
# 17  89.754360   0.025712   17.750000  17.750000  17.750000        NaN
# 18        NaN        NaN         NaN        NaN        NaN        NaN
# 19  69.349202   1.805337         NaN        NaN        NaN        NaN
# 20  89.795796   0.052428    1.125000   1.000000   1.250000   0.176777
# 21        NaN        NaN   33.875000  33.750000  34.000000   0.176777
# 22        NaN        NaN    0.000000   0.000000   0.000000   0.000000
# 23        NaN        NaN         NaN        NaN        NaN        NaN
# 24  84.358097   0.366981    0.993526   0.993526   0.993526        NaN
# 25  69.725775   3.605398         NaN        NaN        NaN        NaN
# 26  89.759727        NaN    1.500000   1.500000   1.500000        NaN
# 27  89.705625   1.023191         NaN        NaN        NaN        NaN
# 28  57.650491   0.854010    0.906235   0.906235   0.906235        NaN
# 29  77.496592   7.211125    2.236068   2.236068   2.236068   0.000000
# 30  86.667333   1.548787    0.000000   0.000000   0.000000        NaN
# 31  89.781442   0.021948    0.000000   0.000000   0.000000        NaN
# 32  82.261478   1.616049   17.697832  17.697832  17.697832        NaN
# 33  77.064227   4.549349    1.191050   1.191050   1.191050        NaN
# 34  49.307657   1.006611    0.000000   0.000000   0.000000   0.000000
# 35  84.493768   0.157601    0.000000   0.000000   0.000000        NaN
# 36  85.894173   0.427769    9.091069   9.091069   9.091069   0.000000
# 37  89.776653   0.016556         NaN        NaN        NaN        NaN
# 38  89.688844   0.007617    0.750000   0.750000   0.750000        NaN
# 39  76.334104   1.837347   13.202010  13.202010  13.202010   0.110294
# 40  72.582073   1.161555   20.500000  20.500000  20.500000   0.353553
# 41  76.377708   2.206110    6.000000   5.500000   6.500000   0.707107
# 42  82.874656   6.308257    0.000000   0.000000   0.000000        NaN
# 43  89.785948   0.014162    6.750000   6.750000   6.750000        NaN
# 44        NaN        NaN   37.361621  37.092350  37.621440   0.263565
# 45        NaN        NaN   11.709879  11.709879  11.709879   0.333714
# 46  89.766783   0.003391   36.250000  36.250000  36.250000        NaN
# 47  87.684200  16.418648         NaN        NaN        NaN        NaN
# 48  81.151801   1.006611    0.000000   0.000000   0.000000   0.000000
# 49  77.221125        NaN         NaN        NaN        NaN        NaN
#
#      target  user
# 0     Still   U12
# 1       Car   U12
# 2     Still   U12
# 3       Car   U12
# 4       Car    U1
# 5       Car    U8
# 6     Train    U7
# 7       Bus   U12
# 8       Bus    U1
# 9     Train    U1
# 10    Still   U10
# 11    Train    U1
# 12      Car   U13
# 13      Car    U1
# 14      Bus    U7
# 15    Still    U1
# 16    Still   U10
# 17      Car    U1
# 18  Walking   U12
# 19    Still    U1
# 20  Walking    U1
# 21      Car    U1
# 22    Still   U12
# 23    Still   U12
# 24    Still   U10
# 25    Train    U7
# 26  Walking    U1
# 27      Bus    U1
# 28    Still   U10
# 29  Walking    U6
# 30      Car    U1
# 31  Walking    U1
# 32      Car   U11
# 33  Walking    U3
# 34      Car    U8
# 35    Still   U10
# 36      Bus    U7
# 37      Bus    U1
# 38  Walking    U1
# 39      Car   U11
# 40      Car    U6
# 41      Car    U6
# 42    Still   U10
# 43      Bus    U1
# 44    Train   U12
# 45      Car   U11
# 46      Car    U1
# 47    Train    U7
# 48      Car    U8
# 49  Walking    U2
#
# [50 rows x 70 columns]

# %%
last_data.sort_values(by='user').head(100)
# Out:
#        time  activityrecognition#1  android.sensor.gravity#std  \
# 2941  205.0                   75.0                2.082523e-07
# 3391   57.0                  100.0                5.528270e-07
# 3393  150.0                   90.0                3.788786e-07
# 3396   91.0                  100.0                7.109474e-07
# 3397  316.0                  100.0                2.468549e-07
# ...     ...                    ...                         ...
# 3148  149.0                  100.0                3.430266e-07
# 3152   38.0                  100.0                5.892149e-07
# 3154   67.0                   69.0                4.224983e-07
# 3155   31.0                  100.0                5.954544e-07
# 3160  162.0                  100.0                1.841698e-07
#
#       android.sensor.magnetic_field#std  \
# 2941                           3.508012
# 3391                           2.390354
# 3393                           0.853995
# 3396                           0.119569
# 3397                           0.675809
# ...                                 ...
# 3148                           0.828670
# 3152                           3.338587
# 3154                           7.310054
# 3155                           0.998618
# 3160                           1.182001
#
#       android.sensor.magnetic_field_uncalibrated#std  \
# 2941                                        3.503187
# 3391                                        1.412490
# 3393                                        2.206598
# 3396                                        0.489907
# 3397                                        0.334487
# ...                                              ...
# 3148                                        0.357445
# 3152                                        1.451180
# 3154                                        0.061163
# 3155                                        0.391801
# 3160                                        1.044655
#
#       android.sensor.orientation#mean  android.sensor.orientation#std  \
# 2941                       183.089448                        0.046953
# 3391                       313.676781                       12.724440
# 3393                       117.326451                        3.686259
# 3396                       138.762082                        0.171203
# 3397                       200.213626                        0.004587
# ...                               ...                             ...
# 3148                       140.413763                        0.205118
# 3152                        40.308019                        0.077762
# 3154                       321.763784                        0.416284
# 3155                       209.681416                        1.084464
# 3160                       337.739082                        0.793563
#
#       android.sensor.rotation_vector#mean  sound#mean   target user  new4_std  \
# 2941                             0.999595   89.770450    Train   U1  0.066737
# 3391                             0.702335   89.780316      Bus   U1  0.462043
# 3393                             0.773390   89.707897  Walking   U1  1.143888
# 3396                             0.935731   70.181361    Still   U1  0.005829
# 3397                             0.971531   89.741919    Still   U1  0.007056
# ...                                   ...         ...      ...  ...       ...
# 3148                             0.940572   89.752382    Train   U1  0.224644
# 3152                             0.343721   89.714712    Train   U1  0.044353
# 3154                             0.990302   89.765937    Train   U1  0.047098
# 3155                             0.962457   89.746445    Train   U1  0.131562
# 3160                             0.341613   89.760291      Car   U1  0.275434
#
#       game_rot_vec_std  mag_field_mean
# 2941          0.000094      127.167884
# 3391          0.014815       72.935872
# 3393          0.036089       88.311214
# 3396          0.000430      107.553049
# 3397          0.000054       95.996250
# ...                ...             ...
# 3148          0.000942      124.254008
# 3152          0.000401       96.631349
# 3154          0.000265       98.843433
# 3155          0.003008      103.587745
# 3160          0.002928      105.413016
#
# [100 rows x 14 columns]

# %%
test_side = last_data.loc[(last_data['user'] == 'U11') | (last_data['user'] == 'U12')]
train_side = last_data.loc[(last_data['user'] != 'U11') &(last_data['user'] != 'U12')]
test_side.to_csv('test_side.csv')
train_side.to_csv('train_side.csv')

# %%
a = last_data - test_side
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     141     try:
# --> 142         result = expressions.evaluate(op, left, right)
#     143     except TypeError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     234             # error: "None" not callable
# --> 235             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     236     return _evaluate_standard(op, op_str, a, b)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      68     with np.errstate(all="ignore"):
# ---> 69         return op(a, b)
#      70
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-377-25b732ffa314> in <module>
# ----> 1 a = last_data - test_side
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arraylike.py in __sub__(self, other)
#      95     @unpack_zerodim_and_defer("__sub__")
#      96     def __sub__(self, other):
# ---> 97         return self._arith_method(other, operator.sub)
#      98
#      99     @unpack_zerodim_and_defer("__rsub__")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _arith_method(self, other, op)
#    5980         self, other = ops.align_method_FRAME(self, other, axis, flex=True, level=None)
#    5981
# -> 5982         new_data = self._dispatch_frame_op(other, op, axis=axis)
#    5983         return self._construct_result(new_data)
#    5984
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _dispatch_frame_op(self, right, func, axis)
#    6016             #  _frame_arith_method_with_reindex
#    6017
# -> 6018             bm = self._mgr.operate_blockwise(right._mgr, array_op)
#    6019             return type(self)(bm)
#    6020
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in operate_blockwise(self, other, array_op)
#     372         Apply array_op blockwise with another (aligned) BlockManager.
#     373         """
# --> 374         return operate_blockwise(self, other, array_op)
#     375
#     376     def apply(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\ops.py in operate_blockwise(left, right, array_op)
#      52     res_blks: List["Block"] = []
#      53     for lvals, rvals, locs, left_ea, right_ea, rblk in _iter_block_pairs(left, right):
# ---> 54         res_values = array_op(lvals, rvals)
#      55         if left_ea and not right_ea and hasattr(res_values, "reshape"):
#      56             res_values = res_values.reshape(1, -1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in arithmetic_op(left, right, op)
#     187     else:
#     188         with np.errstate(all="ignore"):
# --> 189             res_values = _na_arithmetic_op(lvalues, rvalues, op)
#     190
#     191     return res_values
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     147             #  will handle complex numbers incorrectly, see GH#32047
#     148             raise
# --> 149         result = _masked_arith_op(left, right, op)
#     150
#     151     if is_cmp and (is_scalar(result) or result is NotImplemented):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _masked_arith_op(x, y, op)
#      89         if mask.any():
#      90             with np.errstate(all="ignore"):
# ---> 91                 result[mask] = op(xrav[mask], yrav[mask])
#      92
#      93     else:
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
last_data
# Out:
#        time  activityrecognition#1  android.sensor.gravity#std  \
# 1     145.0                  100.0                6.474977e-07
# 3     105.0                   77.0                2.120564e-06
# 4      77.0                  100.0                2.644430e-07
# 6      41.0                  100.0                3.434771e-07
# 8      35.0                  100.0                2.156678e-07
# ...     ...                    ...                         ...
# 5882   30.0                  100.0                3.515019e-07
# 5885    9.0                  100.0                2.282477e-06
# 5886   29.0                   69.0                3.298753e-07
# 5887  158.0                  100.0                8.686595e-07
# 5892   55.0                  100.0                3.594931e-07
#
#       android.sensor.magnetic_field#std  \
# 1                              0.921547
# 3                              0.439461
# 4                              1.104361
# 6                              0.193433
# 8                              0.950412
# ...                                 ...
# 5882                           1.258863
# 5885                           0.653919
# 5886                           1.622119
# 5887                           0.017250
# 5892                           1.073626
#
#       android.sensor.magnetic_field_uncalibrated#std  \
# 1                                           0.506105
# 3                                           0.112446
# 4                                           0.895633
# 6                                           0.248412
# 8                                           0.937387
# ...                                              ...
# 5882                                        1.112556
# 5885                                        0.515132
# 5886                                        0.602059
# 5887                                        0.748186
# 5892                                        0.054675
#
#       android.sensor.orientation#mean  android.sensor.orientation#std  \
# 1                          332.695577                        1.705816
# 3                          373.556039                        8.870011
# 4                          193.201458                      181.729455
# 6                          336.891507                        0.047300
# 8                          131.294098                        1.365320
# ...                               ...                             ...
# 5882                       268.241946                        0.903576
# 5885                        72.742595                        1.301307
# 5886                       226.393623                        0.496985
# 5887                       125.361245                        3.067974
# 5892                       260.716040                      128.622821
#
#       android.sensor.rotation_vector#mean  sound#mean   target user  new4_std  \
# 1                                0.999981   89.200210      Car  U12  0.523398
# 3                                0.998112   87.470377      Car  U12  0.452805
# 4                                0.322242   89.770732      Car   U1  0.452084
# 6                                0.201198   65.158369    Train   U7  0.004987
# 8                                0.780795   89.808441      Bus   U1  0.099817
# ...                                   ...         ...      ...  ...       ...
# 5882                             0.879674   89.762832      Bus   U1  0.233509
# 5885                             0.582695   79.070362      Car  U11  0.201071
# 5886                             0.988151   89.744465    Train   U1  0.031569
# 5887                             0.882573   82.684818    Train   U7  0.088975
# 5892                             0.990902   89.712441  Walking   U1  1.848750
#
#       game_rot_vec_std  mag_field_mean
# 1             0.000028       56.059524
# 3             0.003119       66.790146
# 4             0.045200      117.902468
# 6             0.000105      142.222982
# 8             0.004996       86.115491
# ...                ...             ...
# 5882          0.005179       93.017980
# 5885          0.002919       53.456383
# 5886          0.000268       99.716282
# 5887          0.002125      150.912836
# 5892          0.011728       96.515894
#
# [4117 rows x 14 columns]
