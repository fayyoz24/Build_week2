# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dataset_5secondWindow.csv', index_col=0)
df1 = df.copy()
df1
# Out:
#          id   time  activityrecognition#0  activityrecognition#1  \
# 0     16170   78.0                    NaN                  100.0
# 1     15871  145.0                    NaN                  100.0
# 2     16811  150.0                    NaN                  100.0
# 3     15831  105.0                    NaN                   77.0
# 4       876   77.0                    NaN                  100.0
# ...     ...    ...                    ...                    ...
# 5888  14125    4.0                    NaN                  100.0
# 5889  19582   32.0                    NaN                   10.0
# 5890  16178   86.0                    NaN                  100.0
# 5891  10973  199.0                    NaN                  100.0
# 5892   8278   55.0                    NaN                  100.0
#
#       android.sensor.accelerometer#mean  android.sensor.accelerometer#min  \
# 0                              9.811476                          9.758895
# 1                              9.939207                          7.707437
# 2                              9.827178                          9.804817
# 3                              9.673039                          7.659674
# 4                              9.993466                          8.965621
# ...                                 ...                               ...
# 5888                          10.066610                          4.564648
# 5889                           9.964271                          8.768007
# 5890                           9.812893                          9.772881
# 5891                           9.831144                          9.807347
# 5892                          11.051009                          5.203285
#
#       android.sensor.accelerometer#max  android.sensor.accelerometer#std  \
# 0                             9.849411                          0.014626
# 1                            17.146631                          1.775944
# 2                             9.849262                          0.011199
# 3                            12.304298                          0.862553
# 4                            10.891645                          0.504117
# ...                                ...                               ...
# 5888                         13.414389                          3.373972
# 5889                         11.454213                          0.665529
# 5890                          9.862587                          0.017633
# 5891                          9.874450                          0.013485
# 5892                         19.921068                          4.745098
#
#       android.sensor.game_rotation_vector#mean  \
# 0                                     0.029340
# 1                                     0.999925
# 2                                     0.665215
# 3                                     0.996221
# 4                                     0.563792
# ...                                        ...
# 5888                                  0.986319
# 5889                                  0.648602
# 5890                                  0.024392
# 5891                                  0.481212
# 5892                                  0.919815
#
#       android.sensor.game_rotation_vector#min  ...  sound#mean  sound#min  \
# 0                                    0.029014  ...         NaN        NaN
# 1                                    0.999903  ...   89.200210  89.065143
# 2                                    0.665213  ...         NaN        NaN
# 3                                    0.993781  ...   87.470377  87.470377
# 4                                    0.521799  ...   89.770732  89.770732
# ...                                       ...  ...         ...        ...
# 5888                                 0.974523  ...         NaN        NaN
# 5889                                 0.648343  ...         NaN        NaN
# 5890                                 0.024081  ...         NaN        NaN
# 5891                                 0.481209  ...         NaN        NaN
# 5892                                 0.892571  ...   89.712441  89.712441
#
#       sound#max  sound#std  speed#mean  speed#min  speed#max  speed#std  \
# 0           NaN        NaN    0.000000   0.000000   0.000000   0.000000
# 1     89.335277   0.191013   16.539349  16.539349  16.539349   0.628595
# 2           NaN        NaN    0.000000   0.000000   0.000000   0.000000
# 3     87.470377   2.284186   17.739895  17.739895  17.739895   0.628595
# 4     89.770732   0.006389    9.000000   9.000000   9.000000        NaN
# ...         ...        ...         ...        ...        ...        ...
# 5888        NaN        NaN         NaN        NaN        NaN        NaN
# 5889        NaN        NaN   31.960054  31.960054  31.960054        NaN
# 5890        NaN        NaN    0.000000   0.000000   0.000000   0.000000
# 5891        NaN        NaN    1.090415   1.090415   1.090415        NaN
# 5892  89.712441   0.006400    0.750000   0.750000   0.750000        NaN
#
#        target  user
# 0       Still   U12
# 1         Car   U12
# 2       Still   U12
# 3         Car   U12
# 4         Car    U1
# ...       ...   ...
# 5888  Walking    U2
# 5889    Train    U3
# 5890    Still   U12
# 5891    Still   U10
# 5892  Walking    U1
#
# [5893 rows x 70 columns]

# %%
df1.columns
# Out:
# Index(['id', 'time', 'activityrecognition#0', 'activityrecognition#1',
#        'android.sensor.accelerometer#mean', 'android.sensor.accelerometer#min',
#        'android.sensor.accelerometer#max', 'android.sensor.accelerometer#std',
#        'android.sensor.game_rotation_vector#mean',
#        'android.sensor.game_rotation_vector#min',
#        'android.sensor.game_rotation_vector#max',
#        'android.sensor.game_rotation_vector#std',
#        'android.sensor.gravity#mean', 'android.sensor.gravity#min',
#        'android.sensor.gravity#max', 'android.sensor.gravity#std',
#        'android.sensor.gyroscope#mean', 'android.sensor.gyroscope#min',
#        'android.sensor.gyroscope#max', 'android.sensor.gyroscope#std',
#        'android.sensor.gyroscope_uncalibrated#mean',
#        'android.sensor.gyroscope_uncalibrated#min',
#        'android.sensor.gyroscope_uncalibrated#max',
#        'android.sensor.gyroscope_uncalibrated#std',
#        'android.sensor.light#mean', 'android.sensor.light#min',
#        'android.sensor.light#max', 'android.sensor.light#std',
#        'android.sensor.linear_acceleration#mean',
#        'android.sensor.linear_acceleration#min',
#        'android.sensor.linear_acceleration#max',
#        'android.sensor.linear_acceleration#std',
#        'android.sensor.magnetic_field#mean',
#        'android.sensor.magnetic_field#min',
#        'android.sensor.magnetic_field#max',
#        'android.sensor.magnetic_field#std',
#        'android.sensor.magnetic_field_uncalibrated#mean',
#        'android.sensor.magnetic_field_uncalibrated#min',
#        'android.sensor.magnetic_field_uncalibrated#max',
#        'android.sensor.magnetic_field_uncalibrated#std',
#        'android.sensor.orientation#mean', 'android.sensor.orientation#min',
#        'android.sensor.orientation#max', 'android.sensor.orientation#std',
#        'android.sensor.pressure#mean', 'android.sensor.pressure#min',
#        'android.sensor.pressure#max', 'android.sensor.pressure#std',
#        'android.sensor.proximity#mean', 'android.sensor.proximity#min',
#        'android.sensor.proximity#max', 'android.sensor.proximity#std',
#        'android.sensor.rotation_vector#mean',
#        'android.sensor.rotation_vector#min',
#        'android.sensor.rotation_vector#max',
#        'android.sensor.rotation_vector#std',
#        'android.sensor.step_counter#mean', 'android.sensor.step_counter#min',
#        'android.sensor.step_counter#max', 'android.sensor.step_counter#std',
#        'sound#mean', 'sound#min', 'sound#max', 'sound#std', 'speed#mean',
#        'speed#min', 'speed#max', 'speed#std', 'target', 'user'],
#       dtype='object')

# %%
sorted(df1['user'].unique())
a
# Out:
# ['U1',
#  'U10',
#  'U11',
#  'U12',
#  'U13',
#  'U2',
#  'U3',
#  'U4',
#  'U5',
#  'U6',
#  'U7',
#  'U8',
#  'U9']

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5893 entries, 0 to 5892
# Data columns (total 70 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   id                                               5893 non-null   int64
#  1   time                                             5893 non-null   float64
#  2   activityrecognition#0                            0 non-null      float64
#  3   activityrecognition#1                            5893 non-null   float64
#  4   android.sensor.accelerometer#mean                5893 non-null   float64
#  5   android.sensor.accelerometer#min                 5893 non-null   float64
#  6   android.sensor.accelerometer#max                 5893 non-null   float64
#  7   android.sensor.accelerometer#std                 5893 non-null   float64
#  8   android.sensor.game_rotation_vector#mean         5094 non-null   float64
#  9   android.sensor.game_rotation_vector#min          5094 non-null   float64
#  10  android.sensor.game_rotation_vector#max          5094 non-null   float64
#  11  android.sensor.game_rotation_vector#std          5093 non-null   float64
#  12  android.sensor.gravity#mean                      5396 non-null   float64
#  13  android.sensor.gravity#min                       5396 non-null   float64
#  14  android.sensor.gravity#max                       5396 non-null   float64
#  15  android.sensor.gravity#std                       5356 non-null   float64
#  16  android.sensor.gyroscope#mean                    5173 non-null   float64
#  17  android.sensor.gyroscope#min                     5173 non-null   float64
#  18  android.sensor.gyroscope#max                     5173 non-null   float64
#  19  android.sensor.gyroscope#std                     5172 non-null   float64
#  20  android.sensor.gyroscope_uncalibrated#mean       5094 non-null   float64
#  21  android.sensor.gyroscope_uncalibrated#min        5094 non-null   float64
#  22  android.sensor.gyroscope_uncalibrated#max        5094 non-null   float64
#  23  android.sensor.gyroscope_uncalibrated#std        5094 non-null   float64
#  24  android.sensor.light#mean                        4381 non-null   float64
#  25  android.sensor.light#min                         4381 non-null   float64
#  26  android.sensor.light#max                         4381 non-null   float64
#  27  android.sensor.light#std                         2124 non-null   float64
#  28  android.sensor.linear_acceleration#mean          5399 non-null   float64
#  29  android.sensor.linear_acceleration#min           5399 non-null   float64
#  30  android.sensor.linear_acceleration#max           5399 non-null   float64
#  31  android.sensor.linear_acceleration#std           5370 non-null   float64
#  32  android.sensor.magnetic_field#mean               5400 non-null   float64
#  33  android.sensor.magnetic_field#min                5400 non-null   float64
#  34  android.sensor.magnetic_field#max                5400 non-null   float64
#  35  android.sensor.magnetic_field#std                5383 non-null   float64
#  36  android.sensor.magnetic_field_uncalibrated#mean  5094 non-null   float64
#  37  android.sensor.magnetic_field_uncalibrated#min   5094 non-null   float64
#  38  android.sensor.magnetic_field_uncalibrated#max   5094 non-null   float64
#  39  android.sensor.magnetic_field_uncalibrated#std   5087 non-null   float64
#  40  android.sensor.orientation#mean                  5396 non-null   float64
#  41  android.sensor.orientation#min                   5396 non-null   float64
#  42  android.sensor.orientation#max                   5396 non-null   float64
#  43  android.sensor.orientation#std                   5373 non-null   float64
#  44  android.sensor.pressure#mean                     1918 non-null   float64
#  45  android.sensor.pressure#min                      1918 non-null   float64
#  46  android.sensor.pressure#max                      1918 non-null   float64
#  47  android.sensor.pressure#std                      1128 non-null   float64
#  48  android.sensor.proximity#mean                    1119 non-null   float64
#  49  android.sensor.proximity#min                     1119 non-null   float64
#  50  android.sensor.proximity#max                     1119 non-null   float64
#  51  android.sensor.proximity#std                     283 non-null    float64
#  52  android.sensor.rotation_vector#mean              5172 non-null   float64
#  53  android.sensor.rotation_vector#min               5172 non-null   float64
#  54  android.sensor.rotation_vector#max               5172 non-null   float64
#  55  android.sensor.rotation_vector#std               5163 non-null   float64
#  56  android.sensor.step_counter#mean                 1487 non-null   float64
#  57  android.sensor.step_counter#min                  1487 non-null   float64
#  58  android.sensor.step_counter#max                  1487 non-null   float64
#  59  android.sensor.step_counter#std                  232 non-null    float64
#  60  sound#mean                                       4899 non-null   float64
#  61  sound#min                                        4899 non-null   float64
#  62  sound#max                                        4899 non-null   float64
#  63  sound#std                                        4062 non-null   float64
#  64  speed#mean                                       3520 non-null   float64
#  65  speed#min                                        3520 non-null   float64
#  66  speed#max                                        3520 non-null   float64
#  67  speed#std                                        1318 non-null   float64
#  68  target                                           5893 non-null   object
#  69  user                                             5893 non-null   object
# dtypes: float64(67), int64(1), object(2)
# memory usage: 3.2+ MB

# %%
df1.columns
# Out:
# Index(['id', 'time', 'activityrecognition#0', 'activityrecognition#1',
#        'android.sensor.accelerometer#mean', 'android.sensor.accelerometer#min',
#        'android.sensor.accelerometer#max', 'android.sensor.accelerometer#std',
#        'android.sensor.game_rotation_vector#mean',
#        'android.sensor.game_rotation_vector#min',
#        'android.sensor.game_rotation_vector#max',
#        'android.sensor.game_rotation_vector#std',
#        'android.sensor.gravity#mean', 'android.sensor.gravity#min',
#        'android.sensor.gravity#max', 'android.sensor.gravity#std',
#        'android.sensor.gyroscope#mean', 'android.sensor.gyroscope#min',
#        'android.sensor.gyroscope#max', 'android.sensor.gyroscope#std',
#        'android.sensor.gyroscope_uncalibrated#mean',
#        'android.sensor.gyroscope_uncalibrated#min',
#        'android.sensor.gyroscope_uncalibrated#max',
#        'android.sensor.gyroscope_uncalibrated#std',
#        'android.sensor.light#mean', 'android.sensor.light#min',
#        'android.sensor.light#max', 'android.sensor.light#std',
#        'android.sensor.linear_acceleration#mean',
#        'android.sensor.linear_acceleration#min',
#        'android.sensor.linear_acceleration#max',
#        'android.sensor.linear_acceleration#std',
#        'android.sensor.magnetic_field#mean',
#        'android.sensor.magnetic_field#min',
#        'android.sensor.magnetic_field#max',
#        'android.sensor.magnetic_field#std',
#        'android.sensor.magnetic_field_uncalibrated#mean',
#        'android.sensor.magnetic_field_uncalibrated#min',
#        'android.sensor.magnetic_field_uncalibrated#max',
#        'android.sensor.magnetic_field_uncalibrated#std',
#        'android.sensor.orientation#mean', 'android.sensor.orientation#min',
#        'android.sensor.orientation#max', 'android.sensor.orientation#std',
#        'android.sensor.pressure#mean', 'android.sensor.pressure#min',
#        'android.sensor.pressure#max', 'android.sensor.pressure#std',
#        'android.sensor.proximity#mean', 'android.sensor.proximity#min',
#        'android.sensor.proximity#max', 'android.sensor.proximity#std',
#        'android.sensor.rotation_vector#mean',
#        'android.sensor.rotation_vector#min',
#        'android.sensor.rotation_vector#max',
#        'android.sensor.rotation_vector#std',
#        'android.sensor.step_counter#mean', 'android.sensor.step_counter#min',
#        'android.sensor.step_counter#max', 'android.sensor.step_counter#std',
#        'sound#mean', 'sound#min', 'sound#max', 'sound#std', 'speed#mean',
#        'speed#min', 'speed#max', 'speed#std', 'target', 'user'],
#       dtype='object')

# %%
from sklearn.preprocessing import OrdinalEncoder

enc = OrdinalEncoder()
cat_data = ['user','target']

# %%
import seaborn as sns

# %%
fig, ax = plt.subplots(figsize=(20,20))
ax = sns.heatmap((df1.drop(['target', 'user', 'id', 'activityrecognition#0'], axis=1)).corr(), annot=True)

# %%
a = df1.columns.to_list()
# Out:
# ['id',
#  'time',
#  'activityrecognition#0',
#  'activityrecognition#1',
#  'android.sensor.accelerometer#mean',
#  'android.sensor.accelerometer#min',
#  'android.sensor.accelerometer#max',
#  'android.sensor.accelerometer#std',
#  'android.sensor.game_rotation_vector#mean',
#  'android.sensor.game_rotation_vector#min',
#  'android.sensor.game_rotation_vector#max',
#  'android.sensor.game_rotation_vector#std',
#  'android.sensor.gravity#mean',
#  'android.sensor.gravity#min',
#  'android.sensor.gravity#max',
#  'android.sensor.gravity#std',
#  'android.sensor.gyroscope#mean',
#  'android.sensor.gyroscope#min',
#  'android.sensor.gyroscope#max',
#  'android.sensor.gyroscope#std',
#  'android.sensor.gyroscope_uncalibrated#mean',
#  'android.sensor.gyroscope_uncalibrated#min',
#  'android.sensor.gyroscope_uncalibrated#max',
#  'android.sensor.gyroscope_uncalibrated#std',
#  'android.sensor.light#mean',
#  'android.sensor.light#min',
#  'android.sensor.light#max',
#  'android.sensor.light#std',
#  'android.sensor.linear_acceleration#mean',
#  'android.sensor.linear_acceleration#min',
#  'android.sensor.linear_acceleration#max',
#  'android.sensor.linear_acceleration#std',
#  'android.sensor.magnetic_field#mean',
#  'android.sensor.magnetic_field#min',
#  'android.sensor.magnetic_field#max',
#  'android.sensor.magnetic_field#std',
#  'android.sensor.magnetic_field_uncalibrated#mean',
#  'android.sensor.magnetic_field_uncalibrated#min',
#  'android.sensor.magnetic_field_uncalibrated#max',
#  'android.sensor.magnetic_field_uncalibrated#std',
#  'android.sensor.orientation#mean',
#  'android.sensor.orientation#min',
#  'android.sensor.orientation#max',
#  'android.sensor.orientation#std',
#  'android.sensor.pressure#mean',
#  'android.sensor.pressure#min',
#  'android.sensor.pressure#max',
#  'android.sensor.pressure#std',
#  'android.sensor.proximity#mean',
#  'android.sensor.proximity#min',
#  'android.sensor.proximity#max',
#  'android.sensor.proximity#std',
#  'android.sensor.rotation_vector#mean',
#  'android.sensor.rotation_vector#min',
#  'android.sensor.rotation_vector#max',
#  'android.sensor.rotation_vector#std',
#  'android.sensor.step_counter#mean',
#  'android.sensor.step_counter#min',
#  'android.sensor.step_counter#max',
#  'android.sensor.step_counter#std',
#  'sound#mean',
#  'sound#min',
#  'sound#max',
#  'sound#std',
#  'speed#mean',
#  'speed#min',
#  'speed#max',
#  'speed#std',
#  'target',
#  'user']

# %%
df1_drop_by_corr = df1.drop(['android.sensor.accelerometer#min','android.sensor.accelerometer#max',
'android.sensor.game_rotation_vector#min',
'android.sensor.game_rotation_vector#max', 'android.sensor.gravity#min',
 'android.sensor.gravity#max',  'android.sensor.gyroscope#min',
 'android.sensor.gyroscope#max', 'android.sensor.gyroscope_uncalibrated#min',
 'android.sensor.gyroscope_uncalibrated#max', 'speed#min',
 'speed#max', 'android.sensor.light#min',
 'android.sensor.light#max', 'android.sensor.linear_acceleration#min',
 'android.sensor.linear_acceleration#max','android.sensor.magnetic_field#min',
 'android.sensor.magnetic_field#max', 'android.sensor.magnetic_field_uncalibrated#min',
 'android.sensor.magnetic_field_uncalibrated#max', 'android.sensor.orientation#min',
 'android.sensor.orientation#max', 'android.sensor.pressure#min',
 'android.sensor.pressure#max', 'android.sensor.proximity#min',
 'android.sensor.proximity#max', 'android.sensor.rotation_vector#min',
 'android.sensor.rotation_vector#max','android.sensor.step_counter#min',
 'android.sensor.step_counter#max', 'sound#min',
 'sound#max','id', 'activityrecognition#0'], axis=1)

# %%
a = df1_drop_by_corr.columns.to_list()
a
# Out:
# ['time',
#  'activityrecognition#1',
#  'android.sensor.accelerometer#mean',
#  'android.sensor.accelerometer#std',
#  'android.sensor.game_rotation_vector#mean',
#  'android.sensor.game_rotation_vector#std',
#  'android.sensor.gravity#mean',
#  'android.sensor.gravity#std',
#  'android.sensor.gyroscope#mean',
#  'android.sensor.gyroscope#std',
#  'android.sensor.gyroscope_uncalibrated#mean',
#  'android.sensor.gyroscope_uncalibrated#std',
#  'android.sensor.light#mean',
#  'android.sensor.light#std',
#  'android.sensor.linear_acceleration#mean',
#  'android.sensor.linear_acceleration#std',
#  'android.sensor.magnetic_field#mean',
#  'android.sensor.magnetic_field#std',
#  'android.sensor.magnetic_field_uncalibrated#mean',
#  'android.sensor.magnetic_field_uncalibrated#std',
#  'android.sensor.orientation#mean',
#  'android.sensor.orientation#std',
#  'android.sensor.pressure#mean',
#  'android.sensor.pressure#std',
#  'android.sensor.proximity#mean',
#  'android.sensor.proximity#std',
#  'android.sensor.rotation_vector#mean',
#  'android.sensor.rotation_vector#std',
#  'android.sensor.step_counter#mean',
#  'android.sensor.step_counter#std',
#  'sound#mean',
#  'sound#std',
#  'speed#mean',
#  'speed#std',
#  'target',
#  'user']

# %%
df1_drop_by_corr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5893 entries, 0 to 5892
# Data columns (total 36 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   time                                             5893 non-null   float64
#  1   activityrecognition#1                            5893 non-null   float64
#  2   android.sensor.accelerometer#mean                5893 non-null   float64
#  3   android.sensor.accelerometer#std                 5893 non-null   float64
#  4   android.sensor.game_rotation_vector#mean         5094 non-null   float64
#  5   android.sensor.game_rotation_vector#std          5093 non-null   float64
#  6   android.sensor.gravity#mean                      5396 non-null   float64
#  7   android.sensor.gravity#std                       5356 non-null   float64
#  8   android.sensor.gyroscope#mean                    5173 non-null   float64
#  9   android.sensor.gyroscope#std                     5172 non-null   float64
#  10  android.sensor.gyroscope_uncalibrated#mean       5094 non-null   float64
#  11  android.sensor.gyroscope_uncalibrated#std        5094 non-null   float64
#  12  android.sensor.light#mean                        4381 non-null   float64
#  13  android.sensor.light#std                         2124 non-null   float64
#  14  android.sensor.linear_acceleration#mean          5399 non-null   float64
#  15  android.sensor.linear_acceleration#std           5370 non-null   float64
#  16  android.sensor.magnetic_field#mean               5400 non-null   float64
#  17  android.sensor.magnetic_field#std                5383 non-null   float64
#  18  android.sensor.magnetic_field_uncalibrated#mean  5094 non-null   float64
#  19  android.sensor.magnetic_field_uncalibrated#std   5087 non-null   float64
#  20  android.sensor.orientation#mean                  5396 non-null   float64
#  21  android.sensor.orientation#std                   5373 non-null   float64
#  22  android.sensor.pressure#mean                     1918 non-null   float64
#  23  android.sensor.pressure#std                      1128 non-null   float64
#  24  android.sensor.proximity#mean                    1119 non-null   float64
#  25  android.sensor.proximity#std                     283 non-null    float64
#  26  android.sensor.rotation_vector#mean              5172 non-null   float64
#  27  android.sensor.rotation_vector#std               5163 non-null   float64
#  28  android.sensor.step_counter#mean                 1487 non-null   float64
#  29  android.sensor.step_counter#std                  232 non-null    float64
#  30  sound#mean                                       4899 non-null   float64
#  31  sound#std                                        4062 non-null   float64
#  32  speed#mean                                       3520 non-null   float64
#  33  speed#std                                        1318 non-null   float64
#  34  target                                           5893 non-null   object
#  35  user                                             5893 non-null   object
# dtypes: float64(34), object(2)
# memory usage: 1.8+ MB

# %%
fig, ax = plt.subplots(figsize=(20,20))
ax = sns.heatmap(df1_drop_by_corr.corr(), annot=True)

# %%
#dropping the highly (more than 0.7) correlated features

df1_drop_by_corr1 = df1_drop_by_corr.drop(['android.sensor.accelerometer#mean','android.sensor.linear_acceleration#mean',
'android.sensor.gyroscope#mean', 
'android.sensor.pressure#mean','android.sensor.gyroscope_uncalibrated#mean',
'android.sensor.accelerometer#std','android.sensor.linear_acceleration#std',
'android.sensor.gyroscope_uncalibrated#std','android.sensor.gyroscope#std','android.sensor.light#mean','accelerometer#std_tion#std',
'gyrscope_uncalibrated#std', 'android.sensor.light#std', 'android.sensor.pressure#std',
'android.sensor.proximity#mean','android.sensor.proximity#std', 'android.sensor.step_counter#mean', 'speed#mean','sound#std',
'android.sensor.game_rotation_vector#mean', 'android.sensor.gravity#mean'

], axis=1)

# %%
df1_drop_by_corr1.iloc[:, :].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5893 entries, 0 to 5892
# Data columns (total 18 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   time                                             5893 non-null   float64
#  1   activityrecognition#1                            5893 non-null   float64
#  2   android.sensor.game_rotation_vector#std          5093 non-null   float64
#  3   android.sensor.gravity#std                       5356 non-null   float64
#  4   android.sensor.magnetic_field#mean               5400 non-null   float64
#  5   android.sensor.magnetic_field#std                5383 non-null   float64
#  6   android.sensor.magnetic_field_uncalibrated#mean  5094 non-null   float64
#  7   android.sensor.magnetic_field_uncalibrated#std   5087 non-null   float64
#  8   android.sensor.orientation#mean                  5396 non-null   float64
#  9   android.sensor.orientation#std                   5373 non-null   float64
#  10  android.sensor.rotation_vector#mean              5172 non-null   float64
#  11  android.sensor.rotation_vector#std               5163 non-null   float64
#  12  android.sensor.step_counter#std                  232 non-null    float64
#  13  sound#mean                                       4899 non-null   float64
#  14  speed#std                                        1318 non-null   float64
#  15  target                                           5893 non-null   object
#  16  user                                             5893 non-null   object
#  17  new4_std                                         5065 non-null   float64
# dtypes: float64(16), object(2)
# memory usage: 1003.8+ KB

# %%
df1_drop_by_corr[['android.sensor.accelerometer#std','android.sensor.linear_acceleration#std']]
# Out:
#       android.sensor.accelerometer#std  android.sensor.linear_acceleration#std
# 0                             0.014626                                0.011045
# 1                             1.775944                                0.278730
# 2                             0.011199                                0.011881
# 3                             0.862553                                0.920077
# 4                             0.504117                                1.122225
# ...                                ...                                     ...
# 5888                          3.373972                                0.982225
# 5889                          0.665529                                0.130453
# 5890                          0.017633                                0.008937
# 5891                          0.013485                                0.026978
# 5892                          4.745098                                1.057284
#
# [5893 rows x 2 columns]

# %%
df1_drop_by_corr['accelerometer#std_tion#std'] = df1_drop_by_corr.apply(lambda a: 
(a['android.sensor.accelerometer#std']+a['android.sensor.linear_acceleration#std'])/2, axis=1)

# %%
df1_drop_by_corr[['android.sensor.gyroscope#std',
 'android.sensor.gyroscope_uncalibrated#std']]
# Out:
#       android.sensor.gyroscope#std  android.sensor.gyroscope_uncalibrated#std
# 0                         0.000737                                   0.000982
# 1                         0.020290                                   0.018629
# 2                         0.000713                                   0.000876
# 3                         0.010553                                   0.018037
# 4                         0.098819                                   0.083175
# ...                            ...                                        ...
# 5888                      0.389385                                   0.164709
# 5889                      0.005964                                   0.006740
# 5890                      0.000904                                   0.001057
# 5891                      0.001301                                   0.000402
# 5892                      0.882147                                   0.710473
#
# [5893 rows x 2 columns]

# %%
df1_drop_by_corr['gyrscope_uncalibrated#std'] = df1_drop_by_corr.apply(lambda a:
(a['android.sensor.gyroscope#std']+a['android.sensor.gyroscope_uncalibrated#std'])/2, axis=1)

# %%
df1_drop_by_corr['new4_std'] = df1_drop_by_corr.apply(lambda a:
(a['gyrscope_uncalibrated#std'] + a['accelerometer#std_tion#std'])/2, axis=1)

# %%
fig, ax = plt.subplots(figsize=(20,20))
ax = sns.heatmap(df1_drop_by_corr1.corr(),vmin=-1, vmax=1, annot=True)

# %%
df1_drop_by_corr1.iloc[:, :].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5893 entries, 0 to 5892
# Data columns (total 18 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   time                                             5893 non-null   float64
#  1   activityrecognition#1                            5893 non-null   float64
#  2   android.sensor.game_rotation_vector#std          5093 non-null   float64
#  3   android.sensor.gravity#std                       5356 non-null   float64
#  4   android.sensor.magnetic_field#mean               5400 non-null   float64
#  5   android.sensor.magnetic_field#std                5383 non-null   float64
#  6   android.sensor.magnetic_field_uncalibrated#mean  5094 non-null   float64
#  7   android.sensor.magnetic_field_uncalibrated#std   5087 non-null   float64
#  8   android.sensor.orientation#mean                  5396 non-null   float64
#  9   android.sensor.orientation#std                   5373 non-null   float64
#  10  android.sensor.rotation_vector#mean              5172 non-null   float64
#  11  android.sensor.rotation_vector#std               5163 non-null   float64
#  12  android.sensor.step_counter#std                  232 non-null    float64
#  13  sound#mean                                       4899 non-null   float64
#  14  speed#std                                        1318 non-null   float64
#  15  target                                           5893 non-null   object
#  16  user                                             5893 non-null   object
#  17  new4_std                                         5065 non-null   float64
# dtypes: float64(16), object(2)
# memory usage: 1003.8+ KB

# %%
df1_drop_by_corr[['android.sensor.accelerometer#std','android.sensor.linear_acceleration#std']]
df1_drop_by_corr['accelerometer#std_tion#std'] = df1_drop_by_corr.apply(lambda a: 
(a['android.sensor.accelerometer#std']+a['android.sensor.linear_acceleration#std'])/2, axis=1)
# data['t1_t2'] = data.apply(lambda row: (row['t1']+row['t2'])/2, axis=1)

# %%
df1_drop_by_corr['accelerometer#std_tion#std']
# Out:
# 0       0.012835
# 1       1.027337
# 2       0.011540
# 3       0.891315
# 4       0.813171
#           ...
# 5888    2.178098
# 5889    0.397991
# 5890    0.013285
# 5891    0.020231
# 5892    2.901191
# Name: accelerometer#std_tion#std, Length: 5893, dtype: float64

# %%
a = df1_drop_by_corr1.columns.to_list()
a
# Out:
# ['time',
#  'activityrecognition#1',
#  'android.sensor.game_rotation_vector#mean',
#  'android.sensor.game_rotation_vector#std',
#  'android.sensor.gravity#mean',
#  'android.sensor.gravity#std',
#  'android.sensor.light#std',
#  'android.sensor.magnetic_field#mean',
#  'android.sensor.magnetic_field#std',
#  'android.sensor.magnetic_field_uncalibrated#mean',
#  'android.sensor.magnetic_field_uncalibrated#std',
#  'android.sensor.orientation#mean',
#  'android.sensor.orientation#std',
#  'android.sensor.pressure#std',
#  'android.sensor.proximity#mean',
#  'android.sensor.proximity#std',
#  'android.sensor.rotation_vector#mean',
#  'android.sensor.rotation_vector#std',
#  'android.sensor.step_counter#mean',
#  'android.sensor.step_counter#std',
#  'sound#mean',
#  'sound#std',
#  'speed#mean',
#  'speed#std',
#  'target',
#  'user',
#  'new4_std']

# %%
def correlator(data):
    for i in data.columns:
        print(df1.corrwith(df1[i]).sort_values(ascending=False))
        print(i)

# df1.corrwith(df1[['activityrecognition#1', 'android.sensor.accelerometer#max']]).sort_values(ascending=False)
correlator(df1.drop(['target', 'user'], axis=1))
# Out:
# id                                         1.000000
# android.sensor.step_counter#max            0.578244
# android.sensor.step_counter#mean           0.578230
# android.sensor.step_counter#min            0.578213
# android.sensor.step_counter#std            0.314062
#                                              ...
# android.sensor.game_rotation_vector#min   -0.318258
# sound#max                                 -0.472873
# sound#min                                 -0.473489
# sound#mean                                -0.474967
# activityrecognition#0                           NaN
# Length: 68, dtype: float64
# id
# time                                1.000000
# android.sensor.accelerometer#min    0.251470
# android.sensor.step_counter#min     0.249720
# android.sensor.step_counter#mean    0.249696
# android.sensor.step_counter#max     0.249678
#                                       ...
# id                                 -0.168077
# speed#std                          -0.184678
# android.sensor.accelerometer#std   -0.186240
# android.sensor.step_counter#std    -0.541828
# activityrecognition#0                    NaN
# Length: 68, dtype: float64
# time
# id                                  NaN
# time                                NaN
# activityrecognition#0               NaN
# activityrecognition#1               NaN
# android.sensor.accelerometer#mean   NaN
#                                      ..
# sound#std                           NaN
# speed#mean                          NaN
# speed#min                           NaN
# speed#max                           NaN
# speed#std                           NaN
# Length: 68, dtype: float64
# activityrecognition#0
# activityrecognition#1                1.000000
# speed#min                            0.061495
# android.sensor.gravity#std           0.060928
# speed#mean                           0.060626
# speed#max                            0.059882
#                                        ...
# android.sensor.magnetic_field#max   -0.205422
# android.sensor.step_counter#min     -0.254778
# android.sensor.step_counter#mean    -0.254781
# android.sensor.step_counter#max     -0.254782
# activityrecognition#0                     NaN
# Length: 68, dtype: float64
# activityrecognition#1
# android.sensor.accelerometer#mean             1.000000
# android.sensor.accelerometer#max              0.713901
# android.sensor.accelerometer#std              0.655257
# android.sensor.gyroscope_uncalibrated#mean    0.605308
# android.sensor.gyroscope#mean                 0.599868
#                                                 ...
# android.sensor.step_counter#max              -0.200418
# android.sensor.step_counter#mean             -0.200449
# android.sensor.step_counter#min              -0.200477
# android.sensor.accelerometer#min             -0.350705
# activityrecognition#0                              NaN
# Length: 68, dtype: float64
# android.sensor.accelerometer#mean
# android.sensor.accelerometer#min              1.000000
# android.sensor.step_counter#min               0.328020
# android.sensor.step_counter#mean              0.327991
# android.sensor.step_counter#max               0.327962
# time                                          0.251470
#                                                 ...
# android.sensor.gyroscope_uncalibrated#mean   -0.720242
# android.sensor.gyroscope#mean                -0.732607
# android.sensor.linear_acceleration#mean      -0.747328
# android.sensor.accelerometer#std             -0.868975
# activityrecognition#0                              NaN
# Length: 68, dtype: float64
# android.sensor.accelerometer#min
# android.sensor.accelerometer#max              1.000000
# android.sensor.accelerometer#std              0.870286
# android.sensor.linear_acceleration#max        0.850867
# android.sensor.gyroscope_uncalibrated#mean    0.744873
# android.sensor.gyroscope#mean                 0.741755
#                                                 ...
# android.sensor.step_counter#max              -0.176575
# android.sensor.step_counter#mean             -0.176630
# android.sensor.step_counter#min              -0.176683
# android.sensor.accelerometer#min             -0.701526
# activityrecognition#0                              NaN
# Length: 68, dtype: float64
# android.sensor.accelerometer#max
# android.sensor.accelerometer#std              1.000000
# android.sensor.accelerometer#max              0.870286
# android.sensor.gyroscope#mean                 0.854117
# android.sensor.gyroscope_uncalibrated#mean    0.849276
# android.sensor.linear_acceleration#mean       0.847275
#                                                 ...
# android.sensor.step_counter#max              -0.340229
# android.sensor.step_counter#mean             -0.340263
# android.sensor.step_counter#min              -0.340293
# android.sensor.accelerometer#min             -0.868975
# activityrecognition#0                              NaN
# Length: 68, dtype: float64
# android.sensor.accelerometer#std
# android.sensor.game_rotation_vector#mean    1.000000
# android.sensor.game_rotation_vector#max     0.992792
# android.sensor.game_rotation_vector#min     0.981220
# android.sensor.proximity#std                0.437159
# android.sensor.rotation_vector#max          0.418220
#                                               ...
# android.sensor.step_counter#mean           -0.488150
# android.sensor.step_counter#min            -0.488161
# android.sensor.proximity#mean              -0.533438
# android.sensor.proximity#min               -0.551551
# activityrecognition#0                            NaN
# Length: 68, dtype: float64
# android.sensor.game_rotation_vector#mean
# android.sensor.game_rotation_vector#min     1.000000
# android.sensor.game_rotation_vector#mean    0.981220
# android.sensor.game_rotation_vector#max     0.957008
# android.sensor.rotation_vector#min          0.405937
# android.sensor.rotation_vector#mean         0.398902
#                                               ...
# android.sensor.step_counter#mean           -0.473627
# android.sensor.step_counter#max            -0.473634
# android.sensor.proximity#min               -0.505092
# android.sensor.proximity#mean              -0.509867
# activityrecognition#0                            NaN
# Length: 68, dtype: float64
# android.sensor.game_rotation_vector#min
# android.sensor.game_rotation_vector#max     1.000000
# android.sensor.game_rotation_vector#mean    0.992792
# android.sensor.game_rotation_vector#min     0.957008
# android.sensor.rotation_vector#max          0.428858
# android.sensor.proximity#std                0.425021
#                                               ...
# android.sensor.step_counter#mean           -0.493057
# android.sensor.step_counter#min            -0.493071
# android.sensor.proximity#mean              -0.529141
# android.sensor.proximity#min               -0.556679
# activityrecognition#0                            NaN
# Length: 68, dtype: float64
# android.sensor.game_rotation_vector#max
# android.sensor.game_rotation_vector#std       1.000000
# android.sensor.gyroscope#mean                 0.501612
# android.sensor.gyroscope_uncalibrated#mean    0.500278
# android.sensor.gyroscope_uncalibrated#max     0.494936
# android.sensor.rotation_vector#std            0.493141
#                                                 ...
# speed#max                                    -0.182628
# speed#mean                                   -0.183158
# speed#min                                    -0.183630
# android.sensor.accelerometer#min             -0.397924
# activityrecognition#0                              NaN
# Length: 68, dtype: float64
# android.sensor.game_rotation_vector#std
# android.sensor.gravity#mean      1.000000
# android.sensor.gravity#min       0.980737
# android.sensor.gravity#max       0.977854
# speed#min                        0.119698
# speed#mean                       0.119597
#                                    ...
# android.sensor.proximity#min    -0.234360
# android.sensor.proximity#mean   -0.236878
# android.sensor.gravity#std      -0.240132
# android.sensor.proximity#std    -0.335175
# activityrecognition#0                 NaN
# Length: 68, dtype: float64
# android.sensor.gravity#mean
# android.sensor.gravity#min       1.000000
# android.sensor.gravity#mean      0.980737
# android.sensor.gravity#max       0.918283
# speed#min                        0.118177
# speed#mean                       0.118039
#                                    ...
# android.sensor.proximity#mean   -0.235826
# android.sensor.proximity#min    -0.236845
# android.sensor.proximity#std    -0.274149
# android.sensor.gravity#std      -0.342338
# activityrecognition#0                 NaN
# Length: 68, dtype: float64
# android.sensor.gravity#min
# android.sensor.gravity#max          1.000000
# android.sensor.gravity#mean         0.977854
# android.sensor.gravity#min          0.918283
# android.sensor.step_counter#max     0.126976
# android.sensor.step_counter#mean    0.126968
#                                       ...
# android.sensor.proximity#max       -0.201001
# android.sensor.proximity#min       -0.227332
# android.sensor.proximity#mean      -0.233448
# android.sensor.proximity#std       -0.483565
# activityrecognition#0                    NaN
# Length: 68, dtype: float64
# android.sensor.gravity#max
# android.sensor.gravity#std                         1.000000
# android.sensor.proximity#std                       0.268689
# android.sensor.magnetic_field_uncalibrated#max     0.130388
# android.sensor.proximity#min                       0.129629
# android.sensor.magnetic_field_uncalibrated#mean    0.129491
#                                                      ...
# sound#mean                                        -0.151287
# sound#min                                         -0.154004
# android.sensor.gravity#mean                       -0.240132
# android.sensor.gravity#min                        -0.342338
# activityrecognition#0                                   NaN
# Length: 68, dtype: float64
# android.sensor.gravity#std
# android.sensor.gyroscope#mean                 1.000000
# android.sensor.gyroscope_uncalibrated#mean    0.924417
# android.sensor.gyroscope#max                  0.916175
# android.sensor.gyroscope#std                  0.896271
# android.sensor.gyroscope_uncalibrated#max     0.881598
#                                                 ...
# android.sensor.step_counter#max              -0.329875
# android.sensor.step_counter#mean             -0.329900
# android.sensor.step_counter#min              -0.329921
# android.sensor.accelerometer#min             -0.732607
# activityrecognition#0                              NaN
# Length: 68, dtype: float64
# android.sensor.gyroscope#mean
# android.sensor.gyroscope#min                  1.000000
# android.sensor.gyroscope#mean                 0.773544
# android.sensor.gyroscope_uncalibrated#mean    0.683140
# android.sensor.gyroscope_uncalibrated#min     0.639105
# android.sensor.accelerometer#std              0.617527
#                                                 ...
# speed#min                                    -0.241110
# speed#mean                                   -0.241384
# speed#max                                    -0.241578
# android.sensor.accelerometer#min             -0.565607
# activityrecognition#0                              NaN
# Length: 68, dtype: float64
# android.sensor.gyroscope#min
# android.sensor.gyroscope#max                  1.000000
# android.sensor.gyroscope#std                  0.938073
# android.sensor.gyroscope#mean                 0.916175
# android.sensor.gyroscope_uncalibrated#mean    0.881653
# android.sensor.gyroscope_uncalibrated#max     0.872766
#                                                 ...
# android.sensor.step_counter#max              -0.349435
# android.sensor.step_counter#mean             -0.349460
# android.sensor.step_counter#min              -0.349481
# android.sensor.accelerometer#min             -0.661343
# activityrecognition#0                              NaN
# Length: 68, dtype: float64
# android.sensor.gyroscope#max
# android.sensor.gyroscope#std                  1.000000
# android.sensor.gyroscope#max                  0.938073
# android.sensor.gyroscope#mean                 0.896271
# android.sensor.gyroscope_uncalibrated#mean    0.828469
# android.sensor.gyroscope_uncalibrated#max     0.810229
#                                                 ...
# android.sensor.step_counter#max              -0.327064
# android.sensor.step_counter#mean             -0.327079
# android.sensor.step_counter#min              -0.327090
# android.sensor.accelerometer#min             -0.634131
# activityrecognition#0                              NaN
# Length: 68, dtype: float64
# android.sensor.gyroscope#std
# android.sensor.gyroscope_uncalibrated#mean    1.000000
# android.sensor.gyroscope_uncalibrated#max     0.945636
# android.sensor.gyroscope#mean                 0.924417
# android.sensor.gyroscope#max                  0.881653
# android.sensor.gyroscope_uncalibrated#std     0.880185
#                                                 ...
# android.sensor.step_counter#max              -0.320683
# android.sensor.step_counter#mean             -0.320708
# android.sensor.step_counter#min              -0.320728
# android.sensor.accelerometer#min             -0.720242
# activityrecognition#0                              NaN
# Length: 68, dtype: float64
# android.sensor.gyroscope_uncalibrated#mean
# android.sensor.gyroscope_uncalibrated#min     1.000000
# android.sensor.gyroscope_uncalibrated#mean    0.805874
# android.sensor.gyroscope#mean                 0.736633
# android.sensor.gyroscope#max                  0.665403
# android.sensor.gyroscope#std                  0.654651
#                                                 ...
# speed#min                                    -0.288102
# speed#mean                                   -0.288475
# speed#max                                    -0.288757
# android.sensor.accelerometer#min             -0.570404
# activityrecognition#0                              NaN
# Length: 68, dtype: float64
# android.sensor.gyroscope_uncalibrated#min
# android.sensor.gyroscope_uncalibrated#max     1.000000
# android.sensor.gyroscope_uncalibrated#mean    0.945636
# android.sensor.gyroscope_uncalibrated#std     0.927349
# android.sensor.gyroscope#mean                 0.881598
# android.sensor.gyroscope#max                  0.872766
#                                                 ...
# speed#max                                    -0.290387
# speed#mean                                   -0.290651
# speed#min                                    -0.290770
# android.sensor.accelerometer#min             -0.690907
# activityrecognition#0                              NaN
# Length: 68, dtype: float64
# android.sensor.gyroscope_uncalibrated#max
# android.sensor.gyroscope_uncalibrated#std     1.000000
# android.sensor.gyroscope_uncalibrated#max     0.927349
# android.sensor.gyroscope_uncalibrated#mean    0.880185
# android.sensor.gyroscope#max                  0.821893
# android.sensor.gyroscope#mean                 0.813656
#                                                 ...
# android.sensor.step_counter#max              -0.299365
# android.sensor.step_counter#mean             -0.299381
# android.sensor.step_counter#min              -0.299394
# android.sensor.accelerometer#min             -0.618944
# activityrecognition#0                              NaN
# Length: 68, dtype: float64
# android.sensor.gyroscope_uncalibrated#std
# android.sensor.light#mean          1.000000
# android.sensor.light#max           0.917370
# android.sensor.light#min           0.851032
# android.sensor.light#std           0.617515
# speed#std                          0.281316
#                                      ...
# android.sensor.orientation#mean   -0.110212
# android.sensor.pressure#min       -0.175524
# android.sensor.pressure#mean      -0.175689
# android.sensor.pressure#max       -0.175902
# activityrecognition#0                   NaN
# Length: 68, dtype: float64
# android.sensor.light#mean
# android.sensor.light#min           1.000000
# android.sensor.light#mean          0.851032
# android.sensor.light#max           0.661267
# speed#std                          0.313575
# id                                 0.183579
#                                      ...
# android.sensor.orientation#mean   -0.121104
# android.sensor.pressure#min       -0.212056
# android.sensor.pressure#mean      -0.212344
# android.sensor.pressure#max       -0.212665
# activityrecognition#0                   NaN
# Length: 68, dtype: float64
# android.sensor.light#min
# android.sensor.light#max           1.000000
# android.sensor.light#mean          0.917370
# android.sensor.light#std           0.857964
# android.sensor.light#min           0.661267
# speed#std                          0.244439
#                                      ...
# android.sensor.orientation#mean   -0.093421
# android.sensor.pressure#min       -0.143959
# android.sensor.pressure#mean      -0.144052
# android.sensor.pressure#max       -0.144191
# activityrecognition#0                   NaN
# Length: 68, dtype: float64
# android.sensor.light#max
# android.sensor.light#std             1.000000
# android.sensor.light#max             0.857964
# android.sensor.light#mean            0.617515
# android.sensor.light#min             0.128097
# speed#std                            0.102226
#                                        ...
# android.sensor.magnetic_field#max   -0.072686
# android.sensor.step_counter#min     -0.129403
# android.sensor.step_counter#mean    -0.129410
# android.sensor.step_counter#max     -0.129415
# activityrecognition#0                     NaN
# Length: 68, dtype: float64
# android.sensor.light#std
# android.sensor.linear_acceleration#mean       1.000000
# android.sensor.linear_acceleration#min        0.875712
# android.sensor.accelerometer#std              0.847275
# android.sensor.gyroscope#mean                 0.833014
# android.sensor.gyroscope_uncalibrated#mean    0.820701
#                                                 ...
# android.sensor.step_counter#max              -0.348934
# android.sensor.step_counter#mean             -0.348959
# android.sensor.step_counter#min              -0.348981
# android.sensor.accelerometer#min             -0.747328
# activityrecognition#0                              NaN
# Length: 68, dtype: float64
# android.sensor.linear_acceleration#mean
# android.sensor.linear_acceleration#min        1.000000
# android.sensor.linear_acceleration#mean       0.875712
# android.sensor.gyroscope#mean                 0.700019
# android.sensor.accelerometer#std              0.689172
# android.sensor.gyroscope_uncalibrated#mean    0.683475
#                                                 ...
# android.sensor.step_counter#min              -0.336911
# android.sensor.step_counter#mean             -0.336920
# android.sensor.step_counter#max              -0.336924
# android.sensor.accelerometer#min             -0.634724
# activityrecognition#0                              NaN
# Length: 68, dtype: float64
# android.sensor.linear_acceleration#min
# android.sensor.linear_acceleration#max     1.000000
# android.sensor.accelerometer#max           0.850867
# android.sensor.linear_acceleration#std     0.810004
# android.sensor.linear_acceleration#mean    0.768170
# android.sensor.accelerometer#std           0.731811
#                                              ...
# speed#max                                 -0.164818
# speed#mean                                -0.165779
# speed#min                                 -0.166549
# android.sensor.accelerometer#min          -0.613808
# activityrecognition#0                           NaN
# Length: 68, dtype: float64
# android.sensor.linear_acceleration#max
# android.sensor.linear_acceleration#std     1.000000
# android.sensor.linear_acceleration#max     0.810004
# android.sensor.linear_acceleration#mean    0.786560
# android.sensor.accelerometer#std           0.733075
# android.sensor.gyroscope#mean              0.724124
#                                              ...
# android.sensor.step_counter#max           -0.209649
# android.sensor.step_counter#mean          -0.209686
# android.sensor.step_counter#min           -0.209720
# android.sensor.accelerometer#min          -0.630493
# activityrecognition#0                           NaN
# Length: 68, dtype: float64
# android.sensor.linear_acceleration#std
# android.sensor.magnetic_field#mean                 1.000000
# android.sensor.magnetic_field#min                  0.996202
# android.sensor.magnetic_field#max                  0.995739
# android.sensor.magnetic_field_uncalibrated#max     0.376809
# android.sensor.magnetic_field_uncalibrated#mean    0.376057
#                                                      ...
# android.sensor.gyroscope#max                      -0.124666
# android.sensor.gyroscope#mean                     -0.128121
# activityrecognition#1                             -0.201708
# android.sensor.proximity#std                      -0.556917
# activityrecognition#0                                   NaN
# Length: 68, dtype: float64
# android.sensor.magnetic_field#mean
# android.sensor.magnetic_field#min                  1.000000
# android.sensor.magnetic_field#mean                 0.996202
# android.sensor.magnetic_field#max                  0.985249
# android.sensor.magnetic_field_uncalibrated#mean    0.384559
# android.sensor.magnetic_field_uncalibrated#max     0.384391
#                                                      ...
# android.sensor.gyroscope#max                      -0.140076
# android.sensor.gyroscope#mean                     -0.141991
# activityrecognition#1                             -0.195047
# android.sensor.proximity#std                      -0.576442
# activityrecognition#0                                   NaN
# Length: 68, dtype: float64
# android.sensor.magnetic_field#min
# android.sensor.magnetic_field#max                  1.000000
# android.sensor.magnetic_field#mean                 0.995739
# android.sensor.magnetic_field#min                  0.985249
# android.sensor.magnetic_field_uncalibrated#max     0.367160
# android.sensor.magnetic_field_uncalibrated#mean    0.365199
#                                                      ...
# android.sensor.accelerometer#std                  -0.109944
# android.sensor.gyroscope#mean                     -0.113018
# activityrecognition#1                             -0.205422
# android.sensor.proximity#std                      -0.527925
# activityrecognition#0                                   NaN
# Length: 68, dtype: float64
# android.sensor.magnetic_field#max
# android.sensor.magnetic_field#std                 1.000000
# android.sensor.magnetic_field_uncalibrated#std    0.345554
# android.sensor.magnetic_field#max                 0.182743
# android.sensor.gyroscope#std                      0.165422
# android.sensor.gyroscope#max                      0.152380
#                                                     ...
# android.sensor.proximity#min                     -0.101352
# android.sensor.step_counter#std                  -0.115463
# android.sensor.proximity#max                     -0.119620
# android.sensor.proximity#mean                    -0.125845
# activityrecognition#0                                  NaN
# Length: 68, dtype: float64
# android.sensor.magnetic_field#std
# android.sensor.magnetic_field_uncalibrated#mean    1.000000
# android.sensor.magnetic_field_uncalibrated#min     0.998341
# android.sensor.magnetic_field_uncalibrated#max     0.996552
# android.sensor.magnetic_field#min                  0.384559
# android.sensor.magnetic_field#mean                 0.376057
#                                                      ...
# android.sensor.step_counter#max                   -0.413102
# android.sensor.proximity#std                      -0.438210
# android.sensor.proximity#mean                     -0.492179
# android.sensor.proximity#max                      -0.616495
# activityrecognition#0                                   NaN
# Length: 68, dtype: float64
# android.sensor.magnetic_field_uncalibrated#mean
# android.sensor.magnetic_field_uncalibrated#min     1.000000
# android.sensor.magnetic_field_uncalibrated#mean    0.998341
# android.sensor.magnetic_field_uncalibrated#max     0.990574
# android.sensor.magnetic_field#min                  0.382689
# android.sensor.magnetic_field#mean                 0.373306
#                                                      ...
# android.sensor.step_counter#max                   -0.407751
# android.sensor.proximity#std                      -0.470287
# android.sensor.proximity#mean                     -0.487376
# android.sensor.proximity#max                      -0.614564
# activityrecognition#0                                   NaN
# Length: 68, dtype: float64
# android.sensor.magnetic_field_uncalibrated#min
# android.sensor.magnetic_field_uncalibrated#max     1.000000
# android.sensor.magnetic_field_uncalibrated#mean    0.996552
# android.sensor.magnetic_field_uncalibrated#min     0.990574
# android.sensor.magnetic_field#min                  0.384391
# android.sensor.magnetic_field#mean                 0.376809
#                                                      ...
# android.sensor.step_counter#mean                  -0.418648
# android.sensor.step_counter#max                   -0.418657
# android.sensor.proximity#mean                     -0.496621
# android.sensor.proximity#max                      -0.617724
# activityrecognition#0                                   NaN
# Length: 68, dtype: float64
# android.sensor.magnetic_field_uncalibrated#max
# android.sensor.magnetic_field_uncalibrated#std    1.000000
# android.sensor.magnetic_field#std                 0.345554
# android.sensor.gyroscope#mean                     0.192141
# android.sensor.game_rotation_vector#std           0.190658
# android.sensor.gyroscope_uncalibrated#mean        0.187513
#                                                     ...
# android.sensor.step_counter#mean                 -0.194477
# android.sensor.step_counter#min                  -0.194485
# android.sensor.proximity#max                     -0.197603
# android.sensor.proximity#mean                    -0.212660
# activityrecognition#0                                  NaN
# Length: 68, dtype: float64
# android.sensor.magnetic_field_uncalibrated#std
# android.sensor.orientation#mean    1.000000
# android.sensor.orientation#max     0.943773
# android.sensor.orientation#min     0.931020
# android.sensor.step_counter#std    0.314593
# android.sensor.proximity#std       0.207655
#                                      ...
# speed#min                         -0.123780
# speed#mean                        -0.124528
# speed#max                         -0.125172
# speed#std                         -0.201480
# activityrecognition#0                   NaN
# Length: 68, dtype: float64
# android.sensor.orientation#mean
# android.sensor.orientation#min             1.000000
# android.sensor.orientation#mean            0.931020
# android.sensor.orientation#max             0.795032
# android.sensor.step_counter#min            0.217273
# android.sensor.step_counter#mean           0.217268
#                                              ...
# android.sensor.rotation_vector#std        -0.146288
# android.sensor.game_rotation_vector#std   -0.147290
# speed#std                                 -0.188372
# android.sensor.orientation#std            -0.198378
# activityrecognition#0                           NaN
# Length: 68, dtype: float64
# android.sensor.orientation#min
# android.sensor.orientation#max      1.000000
# android.sensor.orientation#mean     0.943773
# android.sensor.orientation#min      0.795032
# android.sensor.orientation#std      0.317076
# android.sensor.proximity#std        0.243220
#                                       ...
# speed#mean                         -0.154583
# android.sensor.accelerometer#min   -0.154594
# speed#max                          -0.154843
# speed#std                          -0.177867
# activityrecognition#0                    NaN
# Length: 68, dtype: float64
# android.sensor.orientation#max
# android.sensor.orientation#std                1.000000
# android.sensor.gyroscope#mean                 0.443661
# android.sensor.gyroscope_uncalibrated#mean    0.442523
# android.sensor.gyroscope_uncalibrated#max     0.436434
# android.sensor.gyroscope_uncalibrated#std     0.422480
#                                                 ...
# android.sensor.step_counter#mean             -0.190224
# android.sensor.step_counter#min              -0.190229
# android.sensor.orientation#min               -0.198378
# android.sensor.accelerometer#min             -0.349750
# activityrecognition#0                              NaN
# Length: 68, dtype: float64
# android.sensor.orientation#std
# android.sensor.pressure#mean                       1.000000
# android.sensor.pressure#min                        0.999987
# android.sensor.pressure#max                        0.999981
# android.sensor.step_counter#std                    0.898434
# android.sensor.magnetic_field_uncalibrated#mean    0.286692
#                                                      ...
# android.sensor.step_counter#min                   -0.628579
# android.sensor.step_counter#mean                  -0.628607
# android.sensor.step_counter#max                   -0.628627
# android.sensor.proximity#max                      -0.643438
# activityrecognition#0                                   NaN
# Length: 68, dtype: float64
# android.sensor.pressure#mean
# android.sensor.pressure#min                        1.000000
# android.sensor.pressure#mean                       0.999987
# android.sensor.pressure#max                        0.999938
# android.sensor.step_counter#std                    0.898075
# android.sensor.magnetic_field_uncalibrated#mean    0.286810
#                                                      ...
# android.sensor.step_counter#min                   -0.627027
# android.sensor.step_counter#mean                  -0.627055
# android.sensor.step_counter#max                   -0.627075
# android.sensor.proximity#max                      -0.643883
# activityrecognition#0                                   NaN
# Length: 68, dtype: float64
# android.sensor.pressure#min
# android.sensor.pressure#max                        1.000000
# android.sensor.pressure#mean                       0.999981
# android.sensor.pressure#min                        0.999938
# android.sensor.step_counter#std                    0.898593
# android.sensor.magnetic_field_uncalibrated#mean    0.286544
#                                                      ...
# android.sensor.step_counter#min                   -0.630362
# android.sensor.step_counter#mean                  -0.630390
# android.sensor.step_counter#max                   -0.630410
# android.sensor.proximity#max                      -0.642748
# activityrecognition#0                                   NaN
# Length: 68, dtype: float64
# android.sensor.pressure#max
# android.sensor.pressure#std        1.000000
# speed#min                          0.166683
# speed#mean                         0.166537
# speed#max                          0.166299
# sound#min                          0.062419
#                                      ...
# android.sensor.pressure#mean      -0.074914
# android.sensor.pressure#min       -0.082469
# android.sensor.step_counter#std   -0.174347
# sound#std                         -0.258053
# activityrecognition#0                   NaN
# Length: 68, dtype: float64
# android.sensor.pressure#std
# android.sensor.proximity#mean       1.000000
# android.sensor.proximity#max        0.995793
# android.sensor.proximity#min        0.992328
# android.sensor.step_counter#min     0.386270
# android.sensor.step_counter#mean    0.386262
#                                       ...
# android.sensor.pressure#max        -0.543015
# android.sensor.pressure#mean       -0.543249
# android.sensor.pressure#min        -0.543287
# android.sensor.proximity#std       -0.587841
# activityrecognition#0                    NaN
# Length: 68, dtype: float64
# android.sensor.proximity#mean
# android.sensor.proximity#min                1.000000
# android.sensor.proximity#mean               0.992328
# android.sensor.proximity#max                0.977789
# android.sensor.magnetic_field#min           0.268593
# android.sensor.magnetic_field#mean          0.262859
#                                               ...
# android.sensor.game_rotation_vector#min    -0.505092
# android.sensor.game_rotation_vector#mean   -0.551551
# android.sensor.game_rotation_vector#max    -0.556679
# android.sensor.proximity#std               -0.951383
# activityrecognition#0                            NaN
# Length: 68, dtype: float64
# android.sensor.proximity#min
# android.sensor.proximity#max                      1.000000
# android.sensor.proximity#mean                     0.995793
# android.sensor.proximity#min                      0.977789
# android.sensor.step_counter#mean                  0.511415
# android.sensor.step_counter#max                   0.511414
#                                                     ...
# android.sensor.magnetic_field_uncalibrated#max   -0.617724
# android.sensor.pressure#max                      -0.642748
# android.sensor.pressure#mean                     -0.643438
# android.sensor.pressure#min                      -0.643883
# activityrecognition#0                                  NaN
# Length: 68, dtype: float64
# android.sensor.proximity#max
# android.sensor.proximity#std                1.000000
# android.sensor.game_rotation_vector#mean    0.437159
# android.sensor.step_counter#max             0.431229
# android.sensor.step_counter#mean            0.431192
# android.sensor.step_counter#min             0.431142
#                                               ...
# activityrecognition#0                            NaN
# sound#mean                                       NaN
# sound#min                                        NaN
# sound#max                                        NaN
# sound#std                                        NaN
# Length: 68, dtype: float64
# android.sensor.proximity#std
# android.sensor.rotation_vector#mean         1.000000
# android.sensor.rotation_vector#max          0.992259
# android.sensor.rotation_vector#min          0.986021
# android.sensor.game_rotation_vector#max     0.415472
# android.sensor.game_rotation_vector#mean    0.412052
#                                               ...
# android.sensor.step_counter#mean           -0.398880
# android.sensor.step_counter#min            -0.398893
# android.sensor.proximity#min               -0.491519
# android.sensor.step_counter#std            -0.528416
# activityrecognition#0                            NaN
# Length: 68, dtype: float64
# android.sensor.rotation_vector#mean
# android.sensor.rotation_vector#min          1.000000
# android.sensor.rotation_vector#mean         0.986021
# android.sensor.rotation_vector#max          0.961955
# android.sensor.game_rotation_vector#min     0.405937
# android.sensor.game_rotation_vector#mean    0.395651
#                                               ...
# android.sensor.step_counter#mean           -0.387528
# android.sensor.step_counter#min            -0.387530
# android.sensor.step_counter#max            -0.387531
# android.sensor.proximity#min               -0.449166
# activityrecognition#0                            NaN
# Length: 68, dtype: float64
# android.sensor.rotation_vector#min
# android.sensor.rotation_vector#max          1.000000
# android.sensor.rotation_vector#mean         0.992259
# android.sensor.rotation_vector#min          0.961955
# android.sensor.game_rotation_vector#max     0.428858
# android.sensor.game_rotation_vector#mean    0.418220
#                                               ...
# android.sensor.step_counter#mean           -0.397113
# android.sensor.step_counter#min            -0.397132
# android.sensor.proximity#min               -0.504692
# android.sensor.step_counter#std            -0.517233
# activityrecognition#0                            NaN
# Length: 68, dtype: float64
# android.sensor.rotation_vector#max
# android.sensor.rotation_vector#std            1.000000
# android.sensor.game_rotation_vector#std       0.493141
# android.sensor.gyroscope#mean                 0.462780
# android.sensor.gyroscope_uncalibrated#max     0.446706
# android.sensor.gyroscope_uncalibrated#mean    0.443291
#                                                 ...
# speed#min                                    -0.127107
# android.sensor.orientation#min               -0.146288
# android.sensor.rotation_vector#min           -0.188702
# android.sensor.accelerometer#min             -0.350236
# activityrecognition#0                              NaN
# Length: 68, dtype: float64
# android.sensor.rotation_vector#std
# android.sensor.step_counter#mean    1.000000
# android.sensor.step_counter#max     1.000000
# android.sensor.step_counter#min     1.000000
# id                                  0.578230
# android.sensor.proximity#max        0.511415
#                                       ...
# sound#max                          -0.552652
# android.sensor.pressure#min        -0.627055
# android.sensor.pressure#mean       -0.628607
# android.sensor.pressure#max        -0.630390
# activityrecognition#0                    NaN
# Length: 68, dtype: float64
# android.sensor.step_counter#mean
# android.sensor.step_counter#min     1.000000
# android.sensor.step_counter#mean    1.000000
# android.sensor.step_counter#max     1.000000
# id                                  0.578213
# android.sensor.proximity#max        0.511404
#                                       ...
# sound#max                          -0.552654
# android.sensor.pressure#min        -0.627027
# android.sensor.pressure#mean       -0.628579
# android.sensor.pressure#max        -0.630362
# activityrecognition#0                    NaN
# Length: 68, dtype: float64
# android.sensor.step_counter#min
# android.sensor.step_counter#max     1.000000
# android.sensor.step_counter#mean    1.000000
# android.sensor.step_counter#min     1.000000
# id                                  0.578244
# android.sensor.proximity#max        0.511414
#                                       ...
# sound#max                          -0.552651
# android.sensor.pressure#min        -0.627075
# android.sensor.pressure#mean       -0.628627
# android.sensor.pressure#max        -0.630410
# activityrecognition#0                    NaN
# Length: 68, dtype: float64
# android.sensor.step_counter#max
# android.sensor.step_counter#std        1.000000
# android.sensor.pressure#max            0.898593
# android.sensor.pressure#mean           0.898434
# android.sensor.pressure#min            0.898075
# sound#std                              0.331333
#                                          ...
# sound#max                             -0.362183
# android.sensor.rotation_vector#max    -0.517233
# android.sensor.rotation_vector#mean   -0.528416
# time                                  -0.541828
# activityrecognition#0                       NaN
# Length: 68, dtype: float64
# android.sensor.step_counter#std
# sound#mean                                  1.000000
# sound#min                                   0.995955
# sound#max                                   0.995631
# speed#std                                   0.312981
# android.sensor.game_rotation_vector#mean    0.223591
#                                               ...
# android.sensor.step_counter#max            -0.549379
# android.sensor.step_counter#mean           -0.549381
# android.sensor.step_counter#min            -0.549383
# activityrecognition#0                            NaN
# android.sensor.proximity#std                     NaN
# Length: 68, dtype: float64
# sound#mean
# sound#min                                   1.000000
# sound#mean                                  0.995955
# sound#max                                   0.983549
# speed#std                                   0.305807
# android.sensor.game_rotation_vector#mean    0.223643
#                                               ...
# android.sensor.step_counter#max            -0.543197
# android.sensor.step_counter#mean           -0.543199
# android.sensor.step_counter#min            -0.543201
# activityrecognition#0                            NaN
# android.sensor.proximity#std                     NaN
# Length: 68, dtype: float64
# sound#min
# sound#max                                  1.000000
# sound#mean                                 0.995631
# sound#min                                  0.983549
# speed#std                                  0.317451
# android.sensor.game_rotation_vector#max    0.221607
#                                              ...
# android.sensor.step_counter#max           -0.552651
# android.sensor.step_counter#mean          -0.552652
# android.sensor.step_counter#min           -0.552654
# activityrecognition#0                           NaN
# android.sensor.proximity#std                    NaN
# Length: 68, dtype: float64
# sound#max
# sound#std                           1.000000
# android.sensor.step_counter#max     0.367614
# android.sensor.step_counter#mean    0.367613
# android.sensor.step_counter#min     0.367612
# android.sensor.step_counter#std     0.331333
#                                       ...
# sound#max                          -0.330915
# sound#mean                         -0.370366
# sound#min                          -0.404699
# activityrecognition#0                    NaN
# android.sensor.proximity#std             NaN
# Length: 68, dtype: float64
# sound#std
# speed#mean                                    1.000000
# speed#max                                     0.999935
# speed#min                                     0.999903
# android.sensor.magnetic_field#max             0.336854
# android.sensor.magnetic_field#mean            0.332309
#                                                 ...
# android.sensor.gyroscope#max                 -0.302552
# android.sensor.gyroscope#std                 -0.313414
# android.sensor.gyroscope#mean                -0.319803
# android.sensor.gyroscope_uncalibrated#mean   -0.320394
# activityrecognition#0                              NaN
# Length: 68, dtype: float64
# speed#mean
# speed#min                                     1.000000
# speed#mean                                    0.999903
# speed#max                                     0.999688
# android.sensor.magnetic_field#max             0.337204
# android.sensor.magnetic_field#mean            0.332724
#                                                 ...
# android.sensor.gyroscope#max                 -0.302570
# android.sensor.gyroscope#std                 -0.313234
# android.sensor.gyroscope#mean                -0.319723
# android.sensor.gyroscope_uncalibrated#mean   -0.320312
# activityrecognition#0                              NaN
# Length: 68, dtype: float64
# speed#min
# speed#max                                     1.000000
# speed#mean                                    0.999935
# speed#min                                     0.999688
# android.sensor.magnetic_field#max             0.336494
# android.sensor.magnetic_field#mean            0.331896
#                                                 ...
# android.sensor.gyroscope#max                 -0.302396
# android.sensor.gyroscope#std                 -0.313465
# android.sensor.gyroscope#mean                -0.319732
# android.sensor.gyroscope_uncalibrated#mean   -0.320322
# activityrecognition#0                              NaN
# Length: 68, dtype: float64
# speed#max
# speed#std                          1.000000
# sound#max                          0.317451
# android.sensor.light#min           0.313575
# sound#mean                         0.312981
# sound#min                          0.305807
#                                      ...
# android.sensor.step_counter#min   -0.251891
# android.sensor.pressure#min       -0.286480
# android.sensor.pressure#mean      -0.287046
# android.sensor.pressure#max       -0.287579
# activityrecognition#0                   NaN
# Length: 68, dtype: float64
# speed#std

# %%
df2 = df1_dropped.iloc[:, 20:40]
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5893 entries, 0 to 5892
# Data columns (total 20 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   android.sensor.gyroscope_uncalibrated#max        5094 non-null   float64
#  1   android.sensor.gyroscope_uncalibrated#std        5094 non-null   float64
#  2   android.sensor.light#mean                        4381 non-null   float64
#  3   android.sensor.light#min                         4381 non-null   float64
#  4   android.sensor.light#max                         4381 non-null   float64
#  5   android.sensor.linear_acceleration#mean          5399 non-null   float64
#  6   android.sensor.linear_acceleration#min           5399 non-null   float64
#  7   android.sensor.linear_acceleration#max           5399 non-null   float64
#  8   android.sensor.linear_acceleration#std           5370 non-null   float64
#  9   android.sensor.magnetic_field#mean               5400 non-null   float64
#  10  android.sensor.magnetic_field#min                5400 non-null   float64
#  11  android.sensor.magnetic_field#max                5400 non-null   float64
#  12  android.sensor.magnetic_field#std                5383 non-null   float64
#  13  android.sensor.magnetic_field_uncalibrated#mean  5094 non-null   float64
#  14  android.sensor.magnetic_field_uncalibrated#min   5094 non-null   float64
#  15  android.sensor.magnetic_field_uncalibrated#max   5094 non-null   float64
#  16  android.sensor.magnetic_field_uncalibrated#std   5087 non-null   float64
#  17  android.sensor.orientation#mean                  5396 non-null   float64
#  18  android.sensor.orientation#min                   5396 non-null   float64
#  19  android.sensor.orientation#max                   5396 non-null   float64
# dtypes: float64(20)
# memory usage: 966.8 KB

# %%
from sklearn.preprocessing import OrdinalEncoder

enc = OrdinalEncoder()

df_nec = df.copy()

res=enc.fit_transform()

# %%
# df1[df1['android.sensor.gyroscope_uncalibrated#min'].isna()][['target','user']]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5893 entries, 0 to 5892
# Data columns (total 20 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   android.sensor.gyroscope_uncalibrated#max        5094 non-null   float64
#  1   android.sensor.gyroscope_uncalibrated#std        5094 non-null   float64
#  2   android.sensor.light#mean                        4381 non-null   float64
#  3   android.sensor.light#min                         4381 non-null   float64
#  4   android.sensor.light#max                         4381 non-null   float64
#  5   android.sensor.linear_acceleration#mean          5399 non-null   float64
#  6   android.sensor.linear_acceleration#min           5399 non-null   float64
#  7   android.sensor.linear_acceleration#max           5399 non-null   float64
#  8   android.sensor.linear_acceleration#std           5370 non-null   float64
#  9   android.sensor.magnetic_field#mean               5400 non-null   float64
#  10  android.sensor.magnetic_field#min                5400 non-null   float64
#  11  android.sensor.magnetic_field#max                5400 non-null   float64
#  12  android.sensor.magnetic_field#std                5383 non-null   float64
#  13  android.sensor.magnetic_field_uncalibrated#mean  5094 non-null   float64
#  14  android.sensor.magnetic_field_uncalibrated#min   5094 non-null   float64
#  15  android.sensor.magnetic_field_uncalibrated#max   5094 non-null   float64
#  16  android.sensor.magnetic_field_uncalibrated#std   5087 non-null   float64
#  17  android.sensor.orientation#mean                  5396 non-null   float64
#  18  android.sensor.orientation#min                   5396 non-null   float64
#  19  android.sensor.orientation#max                   5396 non-null   float64
# dtypes: float64(20)
# memory usage: 966.8 KB

# %%
df1_dropped = df1_dropped.drop([''], axis=1)

# %%
df3 = df1_dropped.iloc[:,40:]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5893 entries, 0 to 5892
# Data columns (total 11 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   android.sensor.orientation#std       5373 non-null   float64
#  1   android.sensor.rotation_vector#mean  5172 non-null   float64
#  2   android.sensor.rotation_vector#min   5172 non-null   float64
#  3   android.sensor.rotation_vector#max   5172 non-null   float64
#  4   android.sensor.rotation_vector#std   5163 non-null   float64
#  5   sound#mean                           4899 non-null   float64
#  6   sound#min                            4899 non-null   float64
#  7   sound#max                            4899 non-null   float64
#  8   sound#std                            4062 non-null   float64
#  9   target                               5893 non-null   object
#  10  user                                 5893 non-null   object
# dtypes: float64(9), object(2)
# memory usage: 552.5+ KB

# %%
len(df1_dropped.columns)
# Out:
# 51

# %%
df[df['target'] == 'Car']['speed#std'].describe()
# Out:
# count    509.000000
# mean       0.440738
# std        0.609495
# min        0.000000
# 25%        0.012442
# 50%        0.204414
# 75%        0.600782
# max        3.842801
# Name: speed#std, dtype: float64

# %%
df1.corr
# Out:
# <bound method DataFrame.corr of          id   time  activityrecognition#1  android.sensor.accelerometer#mean  \
# 0     16170   78.0                  100.0                           9.811476
# 1     15871  145.0                  100.0                           9.939207
# 2     16811  150.0                  100.0                           9.827178
# 3     15831  105.0                   77.0                           9.673039
# 4       876   77.0                  100.0                           9.993466
# ...     ...    ...                    ...                                ...
# 5888  14125    4.0                  100.0                          10.066610
# 5889  19582   32.0                   10.0                           9.964271
# 5890  16178   86.0                  100.0                           9.812893
# 5891  10973  199.0                  100.0                           9.831144
# 5892   8278   55.0                  100.0                          11.051009
#
#       android.sensor.accelerometer#min  android.sensor.accelerometer#max  \
# 0                             9.758895                          9.849411
# 1                             7.707437                         17.146631
# 2                             9.804817                          9.849262
# 3                             7.659674                         12.304298
# 4                             8.965621                         10.891645
# ...                                ...                               ...
# 5888                          4.564648                         13.414389
# 5889                          8.768007                         11.454213
# 5890                          9.772881                          9.862587
# 5891                          9.807347                          9.874450
# 5892                          5.203285                         19.921068
#
#       android.sensor.accelerometer#std  \
# 0                             0.014626
# 1                             1.775944
# 2                             0.011199
# 3                             0.862553
# 4                             0.504117
# ...                                ...
# 5888                          3.373972
# 5889                          0.665529
# 5890                          0.017633
# 5891                          0.013485
# 5892                          4.745098
#
#       android.sensor.game_rotation_vector#mean  \
# 0                                     0.029340
# 1                                     0.999925
# 2                                     0.665215
# 3                                     0.996221
# 4                                     0.563792
# ...                                        ...
# 5888                                  0.986319
# 5889                                  0.648602
# 5890                                  0.024392
# 5891                                  0.481212
# 5892                                  0.919815
#
#       android.sensor.game_rotation_vector#min  \
# 0                                    0.029014
# 1                                    0.999903
# 2                                    0.665213
# 3                                    0.993781
# 4                                    0.521799
# ...                                       ...
# 5888                                 0.974523
# 5889                                 0.648343
# 5890                                 0.024081
# 5891                                 0.481209
# 5892                                 0.892571
#
#       android.sensor.game_rotation_vector#max  ...  sound#mean  sound#min  \
# 0                                    0.029526  ...         NaN        NaN
# 1                                    0.999946  ...   89.200210  89.065143
# 2                                    0.665218  ...         NaN        NaN
# 3                                    0.998661  ...   87.470377  87.470377
# 4                                    0.672664  ...   89.770732  89.770732
# ...                                       ...  ...         ...        ...
# 5888                                 0.992084  ...         NaN        NaN
# 5889                                 0.648974  ...         NaN        NaN
# 5890                                 0.024696  ...         NaN        NaN
# 5891                                 0.481216  ...         NaN        NaN
# 5892                                 0.944020  ...   89.712441  89.712441
#
#       sound#max  sound#std  speed#mean  speed#min  speed#max  speed#std  \
# 0           NaN        NaN    0.000000   0.000000   0.000000   0.000000
# 1     89.335277   0.191013   16.539349  16.539349  16.539349   0.628595
# 2           NaN        NaN    0.000000   0.000000   0.000000   0.000000
# 3     87.470377   2.284186   17.739895  17.739895  17.739895   0.628595
# 4     89.770732   0.006389    9.000000   9.000000   9.000000        NaN
# ...         ...        ...         ...        ...        ...        ...
# 5888        NaN        NaN         NaN        NaN        NaN        NaN
# 5889        NaN        NaN   31.960054  31.960054  31.960054        NaN
# 5890        NaN        NaN    0.000000   0.000000   0.000000   0.000000
# 5891        NaN        NaN    1.090415   1.090415   1.090415        NaN
# 5892  89.712441   0.006400    0.750000   0.750000   0.750000        NaN
#
#        target  user
# 0       Still   U12
# 1         Car   U12
# 2       Still   U12
# 3         Car   U12
# 4         Car    U1
# ...       ...   ...
# 5888  Walking    U2
# 5889    Train    U3
# 5890    Still   U12
# 5891    Still   U10
# 5892  Walking    U1
#
# [5893 rows x 69 columns]>

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
OrdinalEncoder()
# Out:
# OrdinalEncoder()
